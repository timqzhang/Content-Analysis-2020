# %% [markdown]
# # Week 6 - Vector Space Word Embeddings
#
# This week, we build on last week's topic modeling techniques by taking a text corpus we have developed, specifying an underlying number of dimensions, and training a model with a neural network auto-encoder (one of Google's word2vec  algorithms) that best describes corpus words in their local linguistic contexts, and exploring their locations in the resulting space to learn about the discursive culture that produced them. Documents here are represented as densely indexed locations in dimensions, rather than sparse mixtures of topics (as in LDA topic modeling), so that distances between those documents (and words) are consistently superior, though they require the full vector of dimension loadings (rather than just a few selected topic loadings) to describe. We will explore these spaces to understand complex, semantic relationships between words, index documents with descriptive words, identify the likelihood that a given document would have been produced by a given vector model, and explore how semantic categories can help us understand the cultures that produced them.
#
# For this notebook we will be using the following packages

# %%
#All these packages need to be installed from pip
import gensim#For word2vec, etc
import requests #For downloading our datasets
import lucem_illud_2020

import numpy as np #For arrays
import pandas #Gives us DataFrames
import matplotlib.pyplot as plt #For graphics
import seaborn #Makes the graphics look nicer
import sklearn.metrics.pairwise #For cosine similarity
import sklearn.manifold #For T-SNE
import sklearn.decomposition #For PCA

#This 'magic' command makes the plots work better
#in the notebook, don't use it outside of a notebook.
#Also you can ignore the warning
# %matplotlib inline

import os #For looking through files
import os.path #For managing file paths

# %% [markdown]
# # Getting our corpora
#
# Instead of downloading our corpora, we have download them in advance; a subset of the [senate press releases](https://github.com/lintool/GrimmerSenatePressReleases) are in `grimmerPressReleases`. We will load them into a DataFrame, but first we need to define a function to convert directories of text files into DataFrames:

# %%
def loadDir(targetDir, category):
    allFileNames = os.listdir(targetDir)
    #We need to make them into useable paths and filter out hidden files
    filePaths = [os.path.join(targetDir, fname) for fname in allFileNames if fname[0] != '.']

    #The dict that will become the DataFrame
    senDict = {
        'category' : [category] * len(filePaths),
        'filePath' : [],
        'text' : [],
    }

    for fPath in filePaths:
        with open(fPath) as f:
            senDict['text'].append(f.read())
            senDict['filePath'].append(fPath)

    return pandas.DataFrame(senDict)

# %% [markdown]
# Now we can use the function in all the directories in `data/grimmerPressReleases`

# %%
dataDir = '../data/grimmerPressReleases'

senReleasesDF = pandas.DataFrame()

for senatorName in [d for d in os.listdir(dataDir) if d[0] != '.']:
    senPath = os.path.join(dataDir, senatorName)
    senReleasesDF = senReleasesDF.append(loadDir(senPath, senatorName), ignore_index = True)

senReleasesDF[:100:10]
# Out:
#      category                                           filePath  \
# 0   Klobuchar  ../data/grimmerPressReleases/Klobuchar/22May20...
# 10  Klobuchar  ../data/grimmerPressReleases/Klobuchar/22Aug20...
# 20  Klobuchar  ../data/grimmerPressReleases/Klobuchar/17Jul20...
# 30  Klobuchar  ../data/grimmerPressReleases/Klobuchar/14Dec20...
# 40  Klobuchar  ../data/grimmerPressReleases/Klobuchar/22Jan20...
# 50  Klobuchar  ../data/grimmerPressReleases/Klobuchar/28May20...
# 60  Klobuchar  ../data/grimmerPressReleases/Klobuchar/27Jun20...
# 70  Klobuchar  ../data/grimmerPressReleases/Klobuchar/01Nov20...
# 80  Klobuchar  ../data/grimmerPressReleases/Klobuchar/24Jan20...
# 90  Klobuchar  ../data/grimmerPressReleases/Klobuchar/23Jan20...
#
#                                                  text
# 0                                                 ...
# 10                                                ...
# 20                                                ...
# ...

# %% [markdown]
# Word2Vec needs to retain the sentence structure so as to capture a "continuous bag of words (CBOW)" and all of the skip-grams within a word window. The algorithm tries to preserve the distances induced by one of these two local structures. This is very different from clustering and LDA topic modeling which extract unordered words alone.
#
# When we normalize here, we don't use the lematized form of the word because we might lose information. Note the paramter in the normalize tokens function.

# %%
#Apply our functions, notice each row is a list of lists now
senReleasesDF['tokenized_sents'] = senReleasesDF['text'].apply(lambda x: [lucem_illud_2020.word_tokenize(s) for s in lucem_illud_2020.sent_tokenize(x)])
senReleasesDF['normalized_sents'] = senReleasesDF['tokenized_sents'].apply(lambda x: [lucem_illud_2020.normalizeTokens(s, lemma=False) for s in x])

senReleasesDF[:100:10]
# Out:
#      category                                           filePath  \
# 0   Klobuchar  ../data/grimmerPressReleases/Klobuchar/22May20...
# 10  Klobuchar  ../data/grimmerPressReleases/Klobuchar/22Aug20...
# 20  Klobuchar  ../data/grimmerPressReleases/Klobuchar/17Jul20...
# 30  Klobuchar  ../data/grimmerPressReleases/Klobuchar/14Dec20...
# 40  Klobuchar  ../data/grimmerPressReleases/Klobuchar/22Jan20...
# 50  Klobuchar  ../data/grimmerPressReleases/Klobuchar/28May20...
# 60  Klobuchar  ../data/grimmerPressReleases/Klobuchar/27Jun20...
# 70  Klobuchar  ../data/grimmerPressReleases/Klobuchar/01Nov20...
# 80  Klobuchar  ../data/grimmerPressReleases/Klobuchar/24Jan20...
# 90  Klobuchar  ../data/grimmerPressReleases/Klobuchar/23Jan20...
#
#                                                  text  \
# 0                                                 ...
# 10                                                ...
# 20                                                ...
# ...

# %% [markdown]
# # Word2Vec
#
# We will be using the gensim implementation of [Word2Vec](https://radimrehurek.com/gensim/models/word2vec.html#gensim.models.word2vec.Word2Vec).
#
# To load our data our data we give all the sentences to the trainer:

# %%
senReleasesW2V = gensim.models.word2vec.Word2Vec(senReleasesDF['normalized_sents'].sum())

# %% [markdown]
# Inside the word2vec object the words each have a vector. To access the vector directly, use the square braces (`__getitem__`) method:

# %%
senReleasesW2V['president'][:10] #Shortening because it's very large
# Out:
# array([ 1.6224449 , -1.1412616 , -0.54030615,  0.70567226, -1.0260617 ,
#        -0.28708208, -3.1258454 , -1.073238  ,  1.7746413 , -1.5068388 ],
#       dtype=float32)

# %% [markdown]
# If you want the full matrix, `syn0` stores all the vectors:

# %%
senReleasesW2V.wv.syn0
# Out:
# array([[ 0.14712921,  1.4312841 , -0.14150153, ..., -1.4583215 ,
#         -0.5067579 , -0.62649107],
#        [-0.78941673,  0.7359168 ,  1.2572261 , ..., -2.277009  ,
#          1.3683937 , -1.3274481 ],
#        [-0.577307  ,  0.57759833, -0.587112  , ..., -2.542611  ,
#         -2.4072447 ,  0.91965187],
#        ...,
#        [-0.03585249,  0.04398677, -0.0203485 , ..., -0.02451083,
#         -0.03123697, -0.02470113],
#        [-0.03349424,  0.02932414, -0.01741756, ..., -0.01743883,
#         -0.03573505, -0.01214513],
#        [-0.02287524,  0.06709404,  0.01771656, ..., -0.0563994 ,
#         -0.03389924,  0.01022771]], dtype=float32)

# %% [markdown]
# Then, `index2word` lets you translate from the matrix to words:

# %%
senReleasesW2V.wv.index2word[10]
# Out:
# 'american'

# %% [markdown]
# Now we can look at a few things that come from the word vectors. The first is to find similar vectors (cosine similarity):

# %%
senReleasesW2V.most_similar('president')
# Out:
# [('administration', 0.8293731212615967),
#  ('presidents', 0.7609219551086426),
#  ('administrations', 0.7454638481140137),
#  ('cheney', 0.6283061504364014),
#  ('rollback', 0.6056004762649536),
#  ('ronald', 0.5532345771789551),
#  ('george', 0.5466209053993225),
#  ('republican', 0.5355251431465149),
#  ('speech', 0.533822238445282),
#  ('presidential', 0.5329854488372803)]

# %%
senReleasesW2V.most_similar('war')
# Out:
# [('unresisted', 0.7459019422531128),
#  ('disobedience', 0.7309097051620483),
#  ('wars', 0.6898780465126038),
#  ('afghanistan', 0.6846815347671509),
#  ('liberation', 0.6821036338806152),
#  ('invade', 0.6729146838188171),
#  ('chaos', 0.6613484621047974),
#  ('escalation', 0.6522982716560364),
#  ('misguided', 0.6364195942878723),
#  ('eviction', 0.6335722804069519)]

# %% [markdown]
# Find which word least matches the others within a word set (cosine similarity):

# %%
senReleasesW2V.doesnt_match(['administration', 'administrations', 'presidents', 'president', 'washington'])
# Out:
# 'washington'

# %% [markdown]
# Find which word best matches the result of a semantic *equation* (here, we seek the words whose vectors best fit the missing entry from the equation: **X + Y - Z = _**.

# %%
senReleasesW2V.most_similar(positive=['clinton', 'republican'], negative = ['democrat'])
# Out:
# [('veto', 0.7287009954452515),
#  ('nixon', 0.7005410194396973),
#  ('reagan', 0.6933085918426514),
#  ('bush', 0.6786105632781982),
#  ('lyndon', 0.6773890852928162),
#  ('roosevelt', 0.664299488067627),
#  ('bushs', 0.6611557602882385),
#  ('signature', 0.6588471531867981),
#  ('desk', 0.6556006073951721),
#  ('signing', 0.638512134552002)]

# %% [markdown]
# Here we see that **Clinton + Republican - Democrat = Bush**. In other words, in this dataset, **Clinton** is to **Democrat** as **Bush** is to **Republican**. Whoah!

# %% [markdown]
# We can also save the vectors for later use:

# %%
senReleasesW2V.save("senpressreleasesWORD2Vec")

# %% [markdown]
# We can also use dimension reduction to visulize the vectors. We will start by selecting a subset we want to plot. Let's look at the top words from the set:

# %%
numWords = 50
targetWords = senReleasesW2V.wv.index2word[:numWords]

# %% [markdown]
# We can then extract their vectors and create our own smaller matrix that preserved the distances from the original:

# %%
wordsSubMatrix = []
for word in targetWords:
    wordsSubMatrix.append(senReleasesW2V[word])
wordsSubMatrix = np.array(wordsSubMatrix)
wordsSubMatrix
# Out:
# array([[ 0.14712921,  1.4312841 , -0.14150153, ..., -1.4583215 ,
#         -0.5067579 , -0.62649107],
#        [-0.78941673,  0.7359168 ,  1.2572261 , ..., -2.277009  ,
#          1.3683937 , -1.3274481 ],
#        [-0.577307  ,  0.57759833, -0.587112  , ..., -2.542611  ,
#         -2.4072447 ,  0.91965187],
#        ...,
#        [ 0.08192883,  0.8266091 , -0.18006937, ..., -0.609122  ,
#          3.368779  ,  1.2200042 ],
#        [-0.6156015 ,  1.06012   ,  1.6911286 , ..., -0.9375784 ,
#         -0.11901556,  0.6217097 ],
#        [ 1.2250314 ,  1.8119293 , -0.15565106, ...,  0.39214844,
#         -0.7185931 ,  0.8593414 ]], dtype=float32)

# %% [markdown]
# Then we can use PCA to reduce the dimesions (e.g., to 50), and T-SNE to project them down to the two we will visualize. We note that this is nondeterministic process, and so you can repeat and achieve alternative projectsions/visualizations of the words:

# %%
pcaWords = sklearn.decomposition.PCA(n_components = 50).fit(wordsSubMatrix)
reducedPCA_data = pcaWords.transform(wordsSubMatrix)
#T-SNE is theoretically better, but you should experiment
tsneWords = sklearn.manifold.TSNE(n_components = 2).fit_transform(reducedPCA_data)

# %% [markdown]
# We now can plot the points

# %%
fig = plt.figure(figsize = (10,6))
ax = fig.add_subplot(111)
ax.set_frame_on(False)
plt.scatter(tsneWords[:, 0], tsneWords[:, 1], alpha = 0)#Making the points invisible 
for i, word in enumerate(targetWords):
    ax.annotate(word, (tsneWords[:, 0][i],tsneWords[:, 1][i]), size =  20 * (numWords - i) / numWords)
plt.xticks(())
plt.yticks(())
plt.show()

# %% [markdown]
# My visualization above puts ``said`` next to ``congress`` and ``bill`` near ``act``. ``health`` is beside ``care`` and ``national`` abuts ``security``.

# %% [markdown]
# # Chinese examples

# %%
model=gensim.models.Word2Vec.load('../data/1992embeddings_hs_new3.sg')

# %% [markdown]
# ## analogy
#
# King+man-Queen? A few examples based on a corpus of Chinese news.
#
# First, location analogy: **province -> capital**

# %%
mm = model.most_similar(positive=[u'长沙',u'陕西'], negative=[u'湖南']) # Changsha + Shaanxi - Hunan
for m in mm:
    print(m[0],m[1])
    print("Xi'an")
    break
# Out:
# 西安 0.36609965562820435
# Xi'an

# %%
mm = model.most_similar(positive=[u'广州',u'湖北'], negative=[u'广东']) # Guangzhou + Hubei - Guangdong
for m in mm:
    print(m[0],m[1])
    print("Wuhan")
    break
# Out:
# 武汉 0.3677000105381012
# Wuhan

# %% [markdown]
# Second, location analogy: **country -> capital**

# %%
mm = model.most_similar(positive=[u'东京',u'美国'], negative=[u'日本']) # Tokyo + US - Japan
for m in mm:
    print(m[0],m[1])
    print("(Washington DC)")
    break
# Out:
# 华盛顿 0.508813738822937
# (Washington DC)

# %% [markdown]
# ## similar words

# %%
word = u'社会主义'  #socialism
ss = model.similar_by_word(word,topn=10)
print("the most similar words to " + word + " is: ")
for s in ss:
    print(s[0])
print("")
# Out:
# the most similar words to 社会主义 is:
# 特色
# 市场经济
# 理论
# 建设
# 改革开放
# 马克思主义
# 党
# 经济体制
# 基本路线
# 现代化

# %%
word = u'玉米'  # corn
ss = model.similar_by_word(word,topn=10)
print("the most similar words to " + word + " is: ")
for s in ss:
    print(s[0])
print("")
# Out:
# the most similar words to 玉米 is:
# 小麦
# 水稻
# 作物
# 棉花
# 新品种
# 杂交
# 大豆
# 增产
# 栽培
# 农作物

# %% [markdown]
# ## <span style="color:red">*Exercise 1*</span>
#
# <span style="color:red">Construct cells immediately below this that embed documents related to your final project using at least two different specification of `word2vec`, and visualize them each with two separate visualization layout specifications (e.g., TSNE, PCA). Then interrogate critical word vectors within your corpus in terms of the most similar words, analogies, and other additions and subtractions that reveal the structure of similarity and difference within your semantic space. What does this pattern reveal about the semantic organization of words in your corpora? Which estimation and visualization specification generate the most insight and appear the most robustly supported and why?
#
# <span style="color:red">***Stretch***: Explore different vector calculations beyond addition and subtraction, such as multiplication, division or some other function. What does this exploration reveal about the semantic structure of your corpus?

# %% [markdown]
# I here will use the corpus of public predential speeches from Roosevelt to Obama, ranging from 1933 to 2016.

# %%
import zipfile

# load the corpus

corpus_speech = "/Users/timqzhang/Desktop/UChicago/MACSS_Spring_2020/content_local/Corpus_Speeches"

def loadcorpus(corpus_name):
    texts_raw = {}
    for file in os.listdir(corpus_name + "/"):
        if 'zip' in file:
            print(file)
            zfile = zipfile.ZipFile(corpus_name + "/" + file)
            for file in zfile.namelist():
                if 'txt' in file[6:] and 'SX' not in file:
                    texts_raw[file[6:]] = []
                    with zfile.open(file) as f:
                        for line in f:
                            texts_raw[file[6:]].append(line)
    return texts_raw

speech_raw=loadcorpus(corpus_speech)
# Out:
# bush.zip
# gwbush.zip
# truman.zip
# fdroosevelt.zip
# eisenhower.zip
# obama.zip
# reagan.zip
# lbjohnson.zip
# clinton.zip
# nixon.zip
# ford.zip
# carter.zip
# kennedy.zip

# %%
# clean the non-relevant parts

import re #for regexs

def clean_raw_text2(raw_texts):
    clean_texts = []
    for text in raw_texts:
        try:
            text = text.decode("utf-8")

            clean_text = text.replace("\\'m", "'m").replace("\\'ll", "'ll").replace("\\'re", "'re").replace("\\'s", "'s").replace("\\'re", "'re").replace(" n\'t", "n't").replace("\\'ve", "'ve").replace("\\'d", "'d")
            clean_text= re.sub(r'\n','',clean_text)
            clean_text= re.sub(r'\<\S+\>','',clean_text)
            clean_text= re.sub(r'\<\D+\>','',clean_text)
                
            clean_texts.append(clean_text)
                
        except AttributeError:
            # print("ERROR CLEANING")
            # print(text)
            continue
        except UnicodeDecodeError:
            # print("Unicode Error, Skip")
            continue
    return clean_texts

# %%
# transfer to the dataframe

from datetime import datetime

# here context is a column to indicate the context and purpose of the speech, date is the time when speech is delivered.

speech_dict={'president_name':[],'context':[],'date':[],'text':[]}

for key,value in speech_raw.items():
    
    speech_dict['president_name'].append(key[:key.index('_')].lower())

    for i,content in enumerate(value):
        temp=content.decode('utf-8')
        if '<title' in temp:
            speech_dict['context'].append(temp[temp.index('\"')+1:temp.index('\"',15)])
        elif '<date' in temp:
            speech_dict['date'].append(datetime.strptime(temp[temp.index('\"')+1:temp.index('\"',10)], '%B %d, %Y'))
    
    speech_dict['text'].append(''.join(clean_raw_text2(value[2:])))

# %%
# more cleaning and modifications for dataframe

for key,value in speech_dict.items():
    if key=='president_name':
        for i,content in enumerate(value):
            if content[:3]=='ush':
                speech_dict[key][i]='bush'
            elif content[:3]=='ord':
                speech_dict[key][i]='ford'
            elif '/' in content:
                #print(content)
                speech_dict[key][i]=speech_dict[key][i][speech_dict[key][i].index(r'/')+1:]
    elif key=='text':
        for i,content in enumerate(value):
            if 'r.' in speech_dict[key][i][:3]:
                speech_dict[key][i]=speech_dict[key][i][speech_dict[key][i].index('.')+1:]

speech_df=pandas.DataFrame(speech_dict)
speech_df.sort_values('date',inplace=True)

# %%
speech_df
# Out:
#     president_name                                            context  \
# 92     fdroosevelt                            First Inaugural Address
# 88     fdroosevelt             Fireside Chat 1: On the Banking Crisis
# 95     fdroosevelt  Fireside Chat 2: On Progress During the First ...
# 81     fdroosevelt  Fireside Chat 3: On the National Recovery Admi...
# 84     fdroosevelt              Fireside Chat 4: On Economic Progress
# ..             ...                                                ...
# 173          obama                    2015 State of the Union Address
# 172          obama  Remarks in Eulogy for the Honorable Reverend C...
# 132          obama                    2016 State of the Union Address
# 171          obama                      Remarks to the People of Cuba
# 131          obama         Commencement Address at Rutgers University
#
#           date                                               text
# ...

# %%
#Apply our functions, notice each row is a list of lists now

speech_df['tokenized_sents'] = speech_df['text'].apply(lambda x: [lucem_illud_2020.word_tokenize(s) for s in lucem_illud_2020.sent_tokenize(x)])
speech_df['normalized_sents'] = speech_df['tokenized_sents'].apply(lambda x: [lucem_illud_2020.normalizeTokens(s, lemma=False) for s in x])

# %%
speech_df[::100]
# Out:
#     president_name                                            context  \
# 92     fdroosevelt                            First Inaugural Address
# 403        kennedy  Address at the University of California, Berkeley
# 340           ford                     Republican National Convention
# 282        clinton                                 Address on Somalia
# 167          obama                     Address to the Nation on Syria
#
#           date                                               text  \
# 92  1933-03-04  President Hoover, Mr. Chief Justice, my friend...
# 403 1962-03-23   President, Governor Brown, Dr. Pauley, Chance...
# 340 1976-08-19   Chairman, delegates and alternates to this Re...
# 282 1993-10-07  My fellow Americans:Today I want to talk with ...
# 167 2013-09-10  My fellow Americans, tonight I want to talk to...
#
#                                        tokenized_sents  \
# 92   [[President, Hoover, Mr., Chief, Justice, my, ...
# ...

# %% [markdown]
# ### 1. CBOW model of Word2Vec

# %%
# train the model (CBOW)

speechW2V = gensim.models.word2vec.Word2Vec(speech_df['normalized_sents'].sum())

# %%
speechW2V['president'][:10] #Shortening because it's very large
# Out:
# array([ 0.16231309,  0.51447755, -0.928225  ,  0.31324968,  0.5988887 ,
#        -0.06118277, -0.8890703 , -0.37692243, -0.23480015, -0.37747696],
#       dtype=float32)

# %%
speechW2V.wv.index2word[10]
# Out:
# 'nation'

# %%
# check the most similar words

speechW2V.most_similar('democracy')
# Out:
# [('peoples', 0.9672008156776428),
#  ('cause', 0.9638182520866394),
#  ('neighbors', 0.9623103141784668),
#  ('ideals', 0.9613732099533081),
#  ('determination', 0.957624077796936),
#  ('independence', 0.955304741859436),
#  ('enduring', 0.9497066736221313),
#  ('indivisible', 0.9473209381103516),
#  ('freedom', 0.9466249942779541),
#  ('loving', 0.9466168880462646)]

# %%
speechW2V.most_similar('republican')
# Out:
# [('stevenson', 0.9744806885719299),
#  ('governor', 0.9736596941947937),
#  ('vice', 0.9721904993057251),
#  ('senator', 0.9706683158874512),
#  ('distinguished', 0.9695254564285278),
#  ('khrushchev', 0.9689952731132507),
#  ('bush', 0.9675229787826538),
#  ('mr', 0.9674882888793945),
#  ('gentlemen', 0.9665625095367432),
#  ('representatives', 0.9664463400840759)]

# %%
speechW2V.most_similar('bush')
# Out:
# [('eisenhower', 0.9904775619506836),
#  ('speaker', 0.9897002577781677),
#  ('governor', 0.9859505891799927),
#  ('f.', 0.9851871728897095),
#  ('congressman', 0.9845063090324402),
#  ('chairman', 0.9838389754295349),
#  ('vice', 0.9836914539337158),
#  ('dwight', 0.9831852316856384),
#  ('george', 0.9830095767974854),
#  ('khrushchev', 0.9825542569160461)]

# %%
# check which president doesnt match among all

speechW2V.doesnt_match(['obama', 'gwbush','bush', 
                        'clinton','kennedy','carter',
                        'eisenhower','ford','nixon',
                        'roosevelt','reagan','truman',
                        'johnson'])
# Out:
# 'obama'

# %%
speechW2V.most_similar(positive=['clinton', 'republican'], negative = ['democrat'])
# Out:
# [('bush', 0.9849955439567566),
#  ('senator', 0.9812107086181641),
#  ('representatives', 0.9787365198135376),
#  ('senate', 0.9781513214111328),
#  ('governor', 0.9746642708778381),
#  ('asked', 0.9725307822227478),
#  ('vice', 0.9723822474479675),
#  ('chairman', 0.971382200717926),
#  ('stevenson', 0.9712588787078857),
#  ('eisenhower', 0.9698565006256104)]

# %%
speechW2V.most_similar(positive=['peace', 'war'], negative = ['stable'])
# Out:
# [('ii', 0.7767504453659058),
#  ('cold', 0.7650965452194214),
#  ('end', 0.6836743354797363),
#  ('wars', 0.664837121963501),
#  ('conflict', 0.6485758423805237),
#  ('world', 0.6208459138870239),
#  ('victory', 0.6192294359207153),
#  ('fought', 0.6128522157669067),
#  ('terror', 0.6077860593795776),
#  ('asia', 0.5855879783630371)]

# %%
speechW2V.most_similar(positive=['china','britain'], negative=['korea'])
# Out:
# [('occupies', 0.9529077410697937),
#  ('canada', 0.952006459236145),
#  ('caribbean', 0.9480717778205872),
#  ('closest', 0.9439253211021423),
#  ('seato', 0.9434480667114258),
#  ('republics', 0.9406867027282715),
#  ('organization', 0.9389380216598511),
#  ('resolution', 0.9388483762741089),
#  ('diffuse', 0.9373745322227478),
#  ('prepared', 0.9369562864303589)]

# %%
speechW2V.save("speechWORD2Vec")

# %%
numWords = 50
targetWords = speechW2V.wv.index2word[:numWords]

# %%
wordsSubMatrix = []
for word in targetWords:
    wordsSubMatrix.append(speechW2V[word])
wordsSubMatrix = np.array(wordsSubMatrix)
wordsSubMatrix
# Out:
# array([[-0.5268321 ,  0.01321279, -0.26661542, ..., -0.22157465,
#         -0.16489722,  0.38349968],
#        [ 0.55928534,  0.15683112,  0.22997   , ...,  0.6219312 ,
#         -0.46123457,  0.09631168],
#        [ 0.18545021,  0.1943198 ,  0.17637695, ...,  0.35924813,
#          0.00825159,  0.10853198],
#        ...,
#        [-0.11307845,  0.2939797 , -0.3314291 , ...,  0.24172854,
#          0.6789945 ,  0.06740203],
#        [-0.1903001 , -0.12117867,  0.47901624, ...,  0.10364442,
#         -0.4941315 ,  0.08680737],
#        [ 0.33595198,  0.1265853 , -0.46737552, ...,  0.4577047 ,
#          0.3231394 ,  0.08362231]], dtype=float32)

# %%
# plot via PCA and tsne

pcaWords = sklearn.decomposition.PCA(n_components = 50).fit(wordsSubMatrix)
reducedPCA_data = pcaWords.transform(wordsSubMatrix)
#T-SNE is theoretically better, but you should experiment
tsneWords = sklearn.manifold.TSNE(n_components = 2).fit_transform(reducedPCA_data)

# %%
fig = plt.figure(figsize = (10,6))
ax = fig.add_subplot(111)
ax.set_frame_on(False)
plt.scatter(tsneWords[:, 0], tsneWords[:, 1], alpha = 0)#Making the points invisible 
for i, word in enumerate(targetWords):
    ax.annotate(word, (tsneWords[:, 0][i],tsneWords[:, 1][i]), size =  20 * (numWords - i) / numWords)
plt.xticks(())
plt.yticks(())
plt.title('PCA and TSNE', color = 'red')
plt.show()

# %%
# plot with pca only

fig = plt.figure(figsize = (10,8))
ax = fig.add_subplot(111)
ax.set_frame_on(False)
plt.scatter(reducedPCA_data[:, 0], reducedPCA_data[:, 1], alpha = 0) 

for i, word in enumerate(targetWords):
    ax.annotate(word, (reducedPCA_data[:, 0][i], reducedPCA_data[:, 1][i]), 
                size =  20 * (numWords - i) / numWords)
plt.xticks(())
plt.yticks(())
plt.title('PCA only', color = 'red')
plt.show()

# %% [markdown]
# ### Inference/Comment
#
# The most similar words quite make sense, as for "democracy", we have "people","independence","freedom". For "republican", president Bush, a Republican, is mentioned. And for Bush, another Republican president Eisenhower shows up in the most similar words.
#
# It is interesting to see that among all the presidents from 1933 to now, president Obama is the one that doesn't match. My guess the reason is that he is the first African-American president ever.
#
# I get some meaningful analogies and equations here, meaning that the speeches made by presidents could reveal certain potilic dynamics and some other patterns.
#
# 1. $clinton + republican - democrat = bush/eisenhower$, it is a clear partisan analogy, as Clinton (Democrat) is to Democrat, and Bush/Eisenhower (Republican) are to Republican.
#
# 2. $peace+war-stable=wars/conflicts/terror$, here "peace" is to "stable", and "war" is to "wars","conflicts" and "terror". It makes sense as peaceful environment should also be stable, but warring periods always accompany with conflicts and terror.
#
# 3. $china+britain-korea=canada$, it is a typical location analogy. China is to Korea as they are both Asian and eastern countries, and Canada is to Britain as they are both western countries.
#
# From the graph, "president" and "congress" are linked, "war", "peace" and "freedom" are linked. And comparing the graphs, I think the graph by PCA and TSNE visualizes better.

# %% [markdown]
# ### 2. Skip-gram model of Word2Vec

# %%
# fit the skip gram model

speechW2V2 = gensim.models.word2vec.Word2Vec(speech_df['normalized_sents'].sum(), sg=1, window=10)

# %%
speechW2V2['president'][:10] #Shortening because it's very large
# Out:
# array([ 0.2553818 ,  0.29128158,  0.31730267,  0.4314391 ,  0.02244838,
#         0.09795069, -0.67389214,  0.07618237,  0.02231996, -0.31911978],
#       dtype=float32)

# %%
speechW2V2.wv.index2word[10]
# Out:
# 'nation'

# %%
speechW2V2.most_similar('democracy')
# Out:
# [('inextricably', 0.8096181750297546),
#  ('essence', 0.7996382713317871),
#  ('restoration', 0.795258104801178),
#  ('shares', 0.7947847843170166),
#  ('assemble', 0.7937529683113098),
#  ('indivisible', 0.7885597944259644),
#  ('regain', 0.784135103225708),
#  ('vigilant', 0.781792163848877),
#  ('conviction', 0.7812517881393433),
#  ('ideal', 0.7812056541442871)]

# %%
speechW2V2.most_similar('republican')
# Out:
# [('platform', 0.9121541380882263),
#  ('democrat', 0.8745101690292358),
#  ('party', 0.8544013500213623),
#  ('liberal', 0.8341881036758423),
#  ('nominee', 0.8263496160507202),
#  ('voters', 0.824760913848877),
#  ('candidate', 0.8146622180938721),
#  ('candidates', 0.8102295398712158),
#  ('elect', 0.7996270656585693),
#  ('votes', 0.7983567118644714)]

# %%
speechW2V2.most_similar('bush')
# Out:
# [('gore', 0.9502858519554138),
#  ('carter', 0.9359897375106812),
#  ('george', 0.935592532157898),
#  ('hoover', 0.9339654445648193),
#  ('w.', 0.9308481812477112),
#  ('herbert', 0.9302409887313843),
#  ('clinton', 0.9211092591285706),
#  ('nominated', 0.9159931540489197),
#  ('chair', 0.9149570465087891),
#  ('ford', 0.9106360673904419)]

# %%
speechW2V2.doesnt_match(['obama', 'gwbush','bush', 'clinton','kennedy','carter','eisenhower','ford','nixon','roosevelt','reagan','truman','johnson'])
# Out:
# 'kennedy'

# %%
speechW2V2.most_similar(positive=['clinton', 'republican'], negative = ['democrat'])
# Out:
# [('boehner', 0.8441762924194336),
#  ('gore', 0.8437100052833557),
#  ('predecessor', 0.8422493934631348),
#  ('voted', 0.8413528203964233),
#  ('liberals', 0.8344984650611877),
#  ('nixon', 0.8313620090484619),
#  ('ford', 0.8300225138664246),
#  ('mccain', 0.8242647647857666),
#  ('gratified', 0.8222862482070923),
#  ('congressmen', 0.8221595883369446)]

# %%
speechW2V2.most_similar(positive=['peace', 'war'], negative = ['stable'])
# Out:
# [('ii', 0.5219423174858093),
#  ('terrible', 0.5019831657409668),
#  ('victory', 0.4886578321456909),
#  ('winston', 0.4796905219554901),
#  ('dead', 0.4649049937725067),
#  ('tragic', 0.4647608697414398),
#  ('battles', 0.4634489119052887),
#  ('defeat', 0.4611489176750183),
#  ('conflict', 0.44252461194992065),
#  ('churchill', 0.442251980304718)]

# %%
speechW2V2.most_similar(positive=['china','canada'], negative=['japan'])
# Out:
# [('mexico', 0.7946527004241943),
#  ('france', 0.7855058908462524),
#  ('republics', 0.7828689813613892),
#  ('eastern', 0.776152491569519),
#  ('socialist', 0.77483731508255),
#  ('taiwan', 0.7719416618347168),
#  ('russia', 0.7682974934577942),
#  ('kingdom', 0.7656214237213135),
#  ('relationship', 0.7559592723846436),
#  ('relations', 0.7504596710205078)]

# %%
speechW2V2.save("speechWORD2Vec_sp")

# %%
numWords = 50
targetWords = speechW2V2.wv.index2word[:numWords]

# %%
wordsSubMatrix = []
for word in targetWords:
    wordsSubMatrix.append(speechW2V2[word])
wordsSubMatrix = np.array(wordsSubMatrix)
wordsSubMatrix
# Out:
# array([[-0.31993994,  0.07189026,  0.27186137, ..., -0.11259507,
#          0.4155374 ,  0.1922371 ],
#        [ 0.00839619,  0.27638337,  0.38533702, ...,  0.5175576 ,
#         -0.3729853 ,  0.24897216],
#        [ 0.17706588,  0.2891588 ,  0.15769143, ..., -0.11827412,
#          0.2960456 ,  0.25669196],
#        ...,
#        [-0.32265425,  0.06101122,  0.18989946, ...,  0.03316888,
#          0.40272436,  0.18953334],
#        [-0.1692325 ,  0.35256886,  0.03867062, ...,  0.08615632,
#         -0.00709392, -0.07760575],
#        [ 0.03009394,  0.3589189 ,  0.18405806, ...,  0.68587387,
#          0.10962215, -0.20247144]], dtype=float32)

# %%
# plot via PCA and tsne

pcaWords = sklearn.decomposition.PCA(n_components = 50).fit(wordsSubMatrix)
reducedPCA_data = pcaWords.transform(wordsSubMatrix)
#T-SNE is theoretically better, but you should experiment
tsneWords = sklearn.manifold.TSNE(n_components = 2).fit_transform(reducedPCA_data)

# %%
fig = plt.figure(figsize = (10,6))
ax = fig.add_subplot(111)
ax.set_frame_on(False)
plt.scatter(tsneWords[:, 0], tsneWords[:, 1], alpha = 0)#Making the points invisible 
for i, word in enumerate(targetWords):
    ax.annotate(word, (tsneWords[:, 0][i],tsneWords[:, 1][i]), size =  20 * (numWords - i) / numWords)
plt.xticks(())
plt.yticks(())
plt.title('PCA and TSNE', color = 'red')
plt.show()

# %%
# plot with pca only

fig = plt.figure(figsize = (10,8))
ax = fig.add_subplot(111)
ax.set_frame_on(False)
plt.scatter(reducedPCA_data[:, 0], reducedPCA_data[:, 1], alpha = 0) 

for i, word in enumerate(targetWords):
    ax.annotate(word, (reducedPCA_data[:, 0][i], reducedPCA_data[:, 1][i]), 
                size =  20 * (numWords - i) / numWords)
plt.xticks(())
plt.yticks(())
plt.title('PCA only', color = 'red')
plt.show()

# %% [markdown]
# ### Inference/Comment
#
# The result of skip-gram model is not much different from the CBOW one, except that the president who doesn't match here becomes Kennedy, and I'm not sure why. The patterns from most-similar words and analogies are less meaningful as the ones from CBOW, especially the most-similar words.
#
# For analogies, given the similar $X,Y,Z$ of CBOW, we have:
#
# 1. $clinton + republican - democrat = nixon/mccain$,
#
# 2. $peace+war-stable=terrible/tragic/battles/conflict$,
#
# 3. $china+canada-japan=mexico/france$,
#
# They all make sense to deliver the similar analogies as done in CBOW one.
#
# Still, for the two graphs made by PCA only and PCA and TSNE, the latter one is more clear.

# %% [markdown]
# # Doc2Vec

# %% [markdown]
# Instead of just looking at just how words embed within in the space, we can look at how the different documents relate to each other within the space. First lets load our data--abstracts of most U.S. physics papers from the 1950s.

# %%
apsDF = pandas.read_csv('../data/APSabstracts1950s.csv', index_col = 0)
apsDF[:10]
# Out:
#    copyrightYear                        doi  \
# 0           1950  10.1103/RevModPhys.22.221
# 1           1951  10.1103/RevModPhys.23.147
# 2           1951  10.1103/RevModPhys.23.185
# 3           1951  10.1103/RevModPhys.23.203
# 4           1951   10.1103/RevModPhys.23.21
# 5           1951  10.1103/RevModPhys.23.311
# 6           1951  10.1103/RevModPhys.23.315
# 7           1951  10.1103/RevModPhys.23.322
# 8           1951  10.1103/RevModPhys.23.328
# 9           1952  10.1103/RevModPhys.24.108
#
#                                             abstract
# 0  A summarizing account is given of the research...
# 1  New tables of coulomb functions are presented ...
# 2  Ionization by electron impact in diatomic gase...
# 3  It is shown that the conductivity in the ohmic...
# 4  The factorization method is an operational pro...
# 5  A brief account is given of Dyson's proof of t...
# 6  A systematics is given of all transitions for ...
# ...

# %% [markdown]
# We will load these as documents into Word2Vec, but first we need to normalize and pick some tags.

# %%
keywords = ['photomagnetoelectric', 'quantum', 'boltzmann', 'proton', 'positron', 'feynman', 'classical', 'relativity']

# %%
apsDF['tokenized_words'] = apsDF['abstract'].apply(lambda x: lucem_illud_2020.word_tokenize(x))
apsDF['normalized_words'] = apsDF['tokenized_words'].apply(lambda x: lucem_illud_2020.normalizeTokens(x, lemma=False))

# %%
taggedDocs = []
for index, row in apsDF.iterrows():
    #Just doing a simple keyword assignment
    docKeywords = [s for s in keywords if s in row['normalized_words']]
    docKeywords.append(row['copyrightYear'])
    docKeywords.append(row['doi']) #This lets us extract individual documnets since doi's are unique
    taggedDocs.append(gensim.models.doc2vec.LabeledSentence(words = row['normalized_words'], tags = docKeywords))
apsDF['TaggedAbstracts'] = taggedDocs

# %% [markdown]
# Now we can train a Doc2Vec model:

# %%
apsD2V = gensim.models.doc2vec.Doc2Vec(apsDF['TaggedAbstracts'], size = 100) #Limiting to 100 dimensions
# Out:
# /Users/timqzhang/anaconda3/lib/python3.7/site-packages/gensim/models/doc2vec.py:574: UserWarning: The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.
#   warnings.warn("The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.")

# %% [markdown]
# We can get vectors for the tags/documents, just as we did with words. Documents are actually the centroids (high dimensional average points) of their words.

# %%
apsD2V.docvecs[1952]
# Out:
# array([ 0.2540487 ,  0.28063768,  1.1056944 ,  0.9708537 , -0.6846949 ,
#         0.08647483,  0.10952482, -0.8358619 ,  0.10322934,  1.1260662 ,
#         0.97608703, -1.1611494 ,  0.7210057 ,  0.6350627 ,  2.4547577 ,
#        -1.1726638 , -0.5085941 , -0.34430793, -1.1213362 , -1.395126  ,
#         0.25325418, -1.3627735 , -0.92460227,  0.39771792,  1.1163443 ,
#         0.9142597 , -1.2951201 , -0.94220406, -1.1586754 , -1.5984071 ,
#        -2.728285  , -0.00527506, -0.55867594,  1.865931  ,  0.52466387,
#         0.3266623 , -0.70490116,  1.4735627 , -1.3352317 , -0.03668555,
#        -0.895849  , -0.8061322 , -1.5687288 ,  0.55511653,  0.66458464,
#        -0.5009895 ,  1.2007973 ,  0.21269107,  1.8868264 , -0.5781988 ,
#        -0.6537843 ,  0.59230113,  0.3131351 , -0.954545  , -0.00900492,
#         1.2861822 ,  0.91999197, -0.34523928, -0.7789019 , -1.4422964 ,
#        -0.25483835, -0.4933276 ,  0.17637208,  1.9213136 ,  0.545202  ,
# ...

# %% [markdown]
# The words can still be accessed in the same way:

# %%
apsD2V['atom']
# Out:
# array([ 0.27758524,  1.3047429 , -0.23345134,  0.5628271 , -0.55250335,
#         0.10551208,  0.593324  ,  0.15402578,  0.22974421,  0.48797458,
#         0.40770787, -0.4634567 ,  0.44857183,  0.5953196 ,  0.36351287,
#         0.03369386,  0.5722644 , -0.09518854,  0.49902117, -0.68697536,
#        -0.2816979 , -1.0008571 ,  0.09382805,  0.5011777 , -0.6091562 ,
#        -0.21023338, -0.8192737 ,  0.19821979, -0.72717214, -0.18615064,
#        -0.8984747 , -0.02214801,  0.5039103 , -0.42678267,  0.41483882,
#         0.02921817,  0.46761844,  0.11979216, -0.6558138 , -0.5440697 ,
#         0.40958333,  0.436191  , -1.1175544 , -0.5951349 ,  0.3301206 ,
#        -0.30678025,  0.55633724,  0.67357737,  1.0968649 , -0.02899816,
#        -0.17061108, -0.09621961,  0.3043614 , -0.60422426,  0.85820884,
#        -0.07110265, -0.4820809 ,  0.63126594,  0.48822805,  0.7331068 ,
#        -0.3383744 , -0.0821312 , -0.3438884 , -0.34117547,  0.6095152 ,
# ...

# %% [markdown]
# We can still use the ``most_similar`` command to perform simple semantic equations:

# %%
apsD2V.most_similar(positive = ['atom','electrons'], negative = ['electron'], topn = 1)
# Out:
# [('atoms', 0.8190650939941406)]

# %% [markdown]
# This is interesting. **Electron** is to **electrons** as **atom** is to **atoms**. Another way to understand this, developed below is: **electrons - electron** induces a singular to plural dimension, so when we subtract **electron** from **atom** and add **electrons**, we get **atoms**!

# %%
apsD2V.most_similar(positive = ['einstein','law'], negative = ['equation'], topn = 1)
# Out:
# [('necessitates', 0.9021994471549988)]

# %% [markdown]
# In other words **Einstein** minus **equation** plus **law** equals **Meissner**--Walthur Meissner studied mechanical engineering and physics ... and was more likely to produce a "law" than a "equation", like the Meissner effect, the damping of the magnetic field in superconductors. If we built our word-embedding with a bigger corpus like the entire arXiv, a massive repository of physics preprints, we would see many more such relationships like **gravity - Newton + Einstein = relativity**.

# %% [markdown]
# We can also compute all of these *by hand*--explicitly wth vector algebra:

# %%
sklearn.metrics.pairwise.cosine_similarity(apsD2V['electron'].reshape(1,-1), apsD2V['positron'].reshape(1,-1))
#We reorient the vectors with .reshape(1, -1) so that they can be computed without a warning in sklearn
# Out:
# array([[0.63123316]], dtype=float32)

# %% [markdown]
# In the doc2vec model, the documents have vectors just as the words do, so that we can compare documents with each other and also with words (similar to how a search engine locates a webpage with a query). First, we will calculate the distance between a word and documents in the dataset:

# %%
apsD2V.docvecs.most_similar([ apsD2V['electron'] ], topn=5 )
# Out:
# [('10.1103/PhysRev.113.479', 0.7104884386062622),
#  ('10.1103/PhysRev.90.817', 0.6190904974937439),
#  ('10.1103/PhysRev.110.857', 0.6148364543914795),
#  ('10.1103/PhysRev.89.555', 0.6115856170654297),
#  ('10.1103/PhysRev.89.930', 0.6049326062202454)]

# %% [markdown]
# If we search for the first of these on the web (these are doi codes), we find the following...a pretty good match:

# %%
from IPython.display import Image
Image("../data/PhysRev.98.875.jpg", width=1000, height=1000)

# %% [markdown]
# Now let's go the other way around and find words most similar to this document:

# %%
apsD2V.most_similar( [ apsD2V.docvecs['10.1103/PhysRev.98.875'] ], topn=5)
# Out:
# [('raise', 0.8190820813179016),
#  ('figure', 0.8045439720153809),
#  ('extrapolated', 0.7947718501091003),
#  ('units', 0.7932858467102051),
#  ('unexpected', 0.790429949760437)]

# %% [markdown]
# We can even look for documents most like a query composed of multiple words:

# %%
apsD2V.docvecs.most_similar([ apsD2V['electron']+apsD2V['positron']+apsD2V['neutron']], topn=5 )
# Out:
# [('10.1103/PhysRev.89.1165', 0.7764787077903748),
#  ('10.1103/PhysRev.85.1012', 0.7670782208442688),
#  ('10.1103/PhysRev.108.570', 0.7605031728744507),
#  ('10.1103/PhysRev.84.298', 0.7125542759895325),
#  ('10.1103/PhysRev.101.388', 0.7080934047698975)]

# %% [markdown]
# Now let's plot some words and documents against one another with a heatmap:

# %%
heatmapMatrix = []
for tagOuter in keywords:
    column = []
    tagVec = apsD2V.docvecs[tagOuter].reshape(1, -1)
    for tagInner in keywords:
        column.append(sklearn.metrics.pairwise.cosine_similarity(tagVec, apsD2V.docvecs[tagInner].reshape(1, -1))[0][0])
    heatmapMatrix.append(column)
heatmapMatrix = np.array(heatmapMatrix)

# %%
fig, ax = plt.subplots()
hmap = ax.pcolor(heatmapMatrix, cmap='terrain')
cbar = plt.colorbar(hmap)

cbar.set_label('cosine similarity', rotation=270)
a = ax.set_xticks(np.arange(heatmapMatrix.shape[1]) + 0.5, minor=False)
a = ax.set_yticks(np.arange(heatmapMatrix.shape[0]) + 0.5, minor=False)

a = ax.set_xticklabels(keywords, minor=False, rotation=270)
a = ax.set_yticklabels(keywords, minor=False)

# %% [markdown]
# Now let's look at a heatmap of similarities between the first ten documents in the corpus:

# %%
targetDocs = apsDF['doi'][:10]

heatmapMatrixD = []

for tagOuter in targetDocs:
    column = []
    tagVec = apsD2V.docvecs[tagOuter].reshape(1, -1)
    for tagInner in targetDocs:
        column.append(sklearn.metrics.pairwise.cosine_similarity(tagVec, apsD2V.docvecs[tagInner].reshape(1, -1))[0][0])
    heatmapMatrixD.append(column)
heatmapMatrixD = np.array(heatmapMatrixD)

# %%
fig, ax = plt.subplots()
hmap = ax.pcolor(heatmapMatrixD, cmap='terrain')
cbar = plt.colorbar(hmap)

cbar.set_label('cosine similarity', rotation=270)
a = ax.set_xticks(np.arange(heatmapMatrixD.shape[1]) + 0.5, minor=False)
a = ax.set_yticks(np.arange(heatmapMatrixD.shape[0]) + 0.5, minor=False)

a = ax.set_xticklabels(targetDocs, minor=False, rotation=270)
a = ax.set_yticklabels(targetDocs, minor=False)

# %% [markdown]
# Now let's look at a heatmap of similarities between the first ten documents and our keywords:

# %%
heatmapMatrixC = []

for tagOuter in targetDocs:
    column = []
    tagVec = apsD2V.docvecs[tagOuter].reshape(1, -1)
    for tagInner in keywords:
        column.append(sklearn.metrics.pairwise.cosine_similarity(tagVec, apsD2V.docvecs[tagInner].reshape(1, -1))[0][0])
    heatmapMatrixC.append(column)
heatmapMatrixC = np.array(heatmapMatrixC)

# %%
fig, ax = plt.subplots()
hmap = ax.pcolor(heatmapMatrixC, cmap='terrain')
cbar = plt.colorbar(hmap)

cbar.set_label('cosine similarity', rotation=270)
a = ax.set_xticks(np.arange(heatmapMatrixC.shape[1]) + 0.5, minor=False)
a = ax.set_yticks(np.arange(heatmapMatrixC.shape[0]) + 0.5, minor=False)

a = ax.set_xticklabels(keywords, minor=False, rotation=270)
a = ax.set_yticklabels(targetDocs, minor=False)

# %% [markdown]
# We will save the model in case we would like to use it again.

# %%
apsD2V.save('apsW2V')

# %% [markdown]
# We can later load it:

# %%
#apsD2V = gensim.models.word2vec.Word2Vec.load('data/apsW2V')

# %% [markdown]
# ## <span style="color:red">*Exercise 2*</span>
#
# <span style="color:red">Construct cells immediately below this that embed documents related to your final project using `doc2vec`, and explore the relationship between different documents and the word vectors you analyzed in the last exercise. Consider the most similar words to critical documents, analogies (doc _x_ + word _y_), and other additions and subtractions that reveal the structure of similarity and difference within your semantic space. What does this pattern reveal about the documentary organization of your semantic space?

# %% [markdown]
# I still use the corpus of speech contents from presidents of USA from 1933 to 2016.

# %%
# set the keywords that may be the topics frequently mentioned in president's speeches

keywords = ['education', 'congress', 'energy','religious', 'woman',
            'crime', 'election','gun', 'health', 'china', 'iran',
            'europe', 'welfare','housing', 'budget','war', 
            'immigration', 'terrorism', 'economy']

# tokenize the words

speech_df['tokenized_words'] = speech_df['text'].apply(lambda x: lucem_illud_2020.word_tokenize(x))
speech_df['normalized_words'] = speech_df['tokenized_words'].apply(lambda x: lucem_illud_2020.normalizeTokens(x, lemma=False))

taggedDocs = []
for index, row in speech_df.iterrows():
    #Just doing a simple keyword assignment
    docKeywords = [s for s in keywords if s in row['normalized_words']]
    docKeywords.append(str(row['president_name'])+'-'+str(row['context'])) #president_name+context will be unique
    taggedDocs.append(gensim.models.doc2vec.LabeledSentence(words = row['normalized_words'], tags = docKeywords))
speech_df['Tagged_speech'] = taggedDocs

# %%
# train the model

speechD2V = gensim.models.doc2vec.Doc2Vec(speech_df['Tagged_speech'], vector_size = 100) #Limiting to 100 dimensions

# %%
speechD2V.docvecs[10]
# Out:
# array([ 0.4639926 ,  0.6473521 , -1.0804765 ,  0.7061064 , -0.76921034,
#        -0.41041583, -1.2126302 , -0.6503409 , -0.18536785, -1.0430821 ,
#         0.31091383, -1.1857479 , -0.3188457 ,  1.8975531 ,  0.60729843,
#         0.11256555, -0.42543387,  0.20023797,  0.82167023, -1.1337048 ,
#        -0.4149583 ,  0.14639354,  0.32007837, -0.1044038 , -0.12068307,
#        -0.32774565,  0.05392527,  0.9515363 ,  0.40297464,  0.90209484,
#        -0.48428655, -0.7995048 ,  0.79459697, -0.85780585, -0.5290386 ,
#        -0.34504747, -1.4817531 , -0.67839587, -0.31079966, -0.9410274 ,
#        -0.9132354 , -0.02891962, -2.8041532 ,  1.0978438 , -0.4109726 ,
#        -0.21883923, -0.94652444,  0.39894387,  0.06836627, -0.90996236,
#         0.3322058 , -0.25978085,  1.1628294 ,  0.93405   ,  0.07030895,
#        -0.52289176,  0.96529084, -0.39022377,  0.46005175,  0.1815794 ,
#        -0.6989479 , -1.6402866 , -0.77484024,  0.36241058, -0.1078686 ,
# ...

# %%
speechD2V.most_similar(positive=['war', 'weapons'], negative = ['peace'], topn = 10)
# Out:
# [('military', 0.9374706149101257),
#  ('nuclear', 0.9333921670913696),
#  ('limitation', 0.9314414262771606),
#  ('polaris', 0.9223387837409973),
#  ('arms', 0.92134690284729),
#  ('tactical', 0.9199084043502808),
#  ('banning', 0.9196137189865112),
#  ('conventional', 0.9163005352020264),
#  ('strategic', 0.9156255125999451),
#  ('missiles', 0.9125586748123169)]

# %%
speechD2V.most_similar(positive=['laden', 'terrorism'], negative = ['stable'], topn = 10)
# Out:
# [('unarmed', 0.9745135307312012),
#  ('brutal', 0.9599090814590454),
#  ('boat', 0.9592331051826477),
#  ('mccaffrey', 0.9576424360275269),
#  ('ink', 0.956486701965332),
#  ('terrifying', 0.9548274278640747),
#  ('hero', 0.9546696543693542),
#  ('divisive', 0.9514898657798767),
#  ('crashed', 0.9450369477272034),
#  ('animosities', 0.9443593621253967)]

# %%
speechD2V.docvecs.most_similar([ speechD2V['crisis'] ], topn=5 )
# Out:
# [('carter-Speech on Establishing Diplomatic Relations with China',
#   0.9868929386138916),
#  ('reagan-Address to the Bundestag in West Germany', 0.9795928597450256),
#  ('clinton-Statement on Kosovo', 0.9750188589096069),
#  ('clinton-Remarks on Operation Restore Hope', 0.9696681499481201),
#  ('bush-Address on the End of the Gulf War', 0.9681750535964966)]

# %%
speechD2V.docvecs.most_similar([ speechD2V['welfare'] ], topn=5 )
# Out:
# [('reagan-Remarks on Signing the Tax Reform Act', 0.979637622833252),
#  ('carter-University of Notre Dame Commencement', 0.9716901779174805),
#  ('reagan-Address Announcing His Candidacy for Reelection',
#   0.9526599645614624),
#  ('gwbush-Speech on New Mother and Child HIV Prevention Initiative',
#   0.9500317573547363),
#  ('bush-Address to the Nation on the Budget', 0.9330294132232666)]

# %%
speechD2V.docvecs.most_similar([ speechD2V['recover'] ], topn=5 )
# Out:
# [('bush-Address to the Nation on the Budget', 0.9778828024864197),
#  ('obama-Address to the Nation on Immigration', 0.9753937721252441),
#  ('lbjohnson-Remarks upon Signing the Civil Rights Bill', 0.9725099802017212),
#  ('bush-Remarks on the Signing of the Americans with Disabilities Act',
#   0.9696474075317383),
#  ('truman-Report to the American People on Korea', 0.9632237553596497)]

# %%
speechD2V.most_similar( [ speechD2V.docvecs['obama-Address to the Nation on Immigration'] ], topn=10)
# Out:
# [('enrollment', 0.9919825792312622),
#  ('legally', 0.9912427067756653),
#  ('infected', 0.9902464747428894),
#  ('badly', 0.9898508787155151),
#  ('estate', 0.9894607663154602),
#  ('expensive', 0.9892987608909607),
#  ('equity', 0.9876383543014526),
#  ('fairness', 0.9876158237457275),
#  ('holding', 0.9870505332946777),
#  ('stay', 0.9869891405105591)]

# %%
speechD2V.docvecs.most_similar([ speechD2V['war']+speechD2V['vietnam']], topn=5 )
# Out:
# [('fdroosevelt-Fireside Chat 16: On the Arsenal of Democracy',
#   0.9478118419647217),
#  ('fdroosevelt-State of the Union', 0.9412587285041809),
#  ('gwbush-Second Inaugural Address', 0.9406769275665283),
#  ("carter-President Carter's Remarks on Joint Statement at Camp David Summit",
#   0.9122126698493958),
#  ('nixon-Address to the Nation on the War in Vietnam', 0.9110877513885498)]

# %% [markdown]
# ### Inference/Comment
#
# The word analogies all makes sense, as "war"+"weapon" will cause more intense conflicts, and minus "peace" will make situations even worse, so the result is "military" or even "nuclear". Also, "laden"+"terrorism"-"stable" will cause more severe terrorism which is "brutal" and "animosity".
#
# The speeches around "crisis" makes sense, as the speeches cover the Kosovo and Gulf war, also the renormalization with China. The speeches around the "welfare" mainly covers the health, tax reduction and budget. For "recover", it mainly has budget, civil rights and disabilities.
#
# The words around "Address to the Nation on Immigration", a speech by Obama, concern the fairness and legality, which among the key issues for immigrants.
#
# Also, for the word combo "vietnam war", we have the speech from Nixon on the Vietnam war "Address to the Nation on the War in Vietnam".

# %%
# draw the heatmaps between keywords

heatmapMatrix = []
for tagOuter in keywords:
    column = []
    tagVec = speechD2V.docvecs[tagOuter].reshape(1, -1)
    for tagInner in keywords:
        column.append(sklearn.metrics.pairwise.cosine_similarity(tagVec, speechD2V.docvecs[tagInner].reshape(1, -1))[0][0])
    heatmapMatrix.append(column)
heatmapMatrix = np.array(heatmapMatrix)

# %%
fig, ax = plt.subplots()
hmap = ax.pcolor(heatmapMatrix, cmap='terrain')
cbar = plt.colorbar(hmap)

cbar.set_label('cosine similarity', rotation=270)
a = ax.set_xticks(np.arange(heatmapMatrix.shape[1]) + 0.5, minor=False)
a = ax.set_yticks(np.arange(heatmapMatrix.shape[0]) + 0.5, minor=False)

a = ax.set_xticklabels(keywords, minor=False, rotation=270)
a = ax.set_yticklabels(keywords, minor=False)

# %% [markdown]
# ### Inference/Comment
#
# For the heatmap between keywords, budget and housing is quite linked, and we see that education has many similar words like crime, woman, religious, energy, welfare, housing and immigration, indicating that education is an impoertant topic in the speeches.

# %%
# as speeches by different presidents may hard to compare, I here control the speech just by Bush GW.

speech_names = list(speech_df['president_name']+'-'+speech_df['context'])

targetDocs = [x for x in speech_names if 'gwbush' in x][:15]

heatmapMatrixD = []

for tagOuter in targetDocs:
    column = []
    tagVec = speechD2V.docvecs[tagOuter].reshape(1, -1)
    for tagInner in targetDocs:
        column.append(sklearn.metrics.pairwise.cosine_similarity(tagVec, speechD2V.docvecs[tagInner].reshape(1, -1))[0][0])
    heatmapMatrixD.append(column)
heatmapMatrixD = np.array(heatmapMatrixD)

# %%
fig, ax = plt.subplots()
hmap = ax.pcolor(heatmapMatrixD, cmap='terrain')
cbar = plt.colorbar(hmap)

cbar.set_label('cosine similarity', rotation=270)
a = ax.set_xticks(np.arange(heatmapMatrixD.shape[1]) + 0.5, minor=False)
a = ax.set_yticks(np.arange(heatmapMatrixD.shape[0]) + 0.5, minor=False)

a = ax.set_xticklabels(targetDocs, minor=False, rotation=270)
a = ax.set_yticklabels(targetDocs, minor=False)

# %% [markdown]
# ### Inference/Comment
#
# For the heatmap between speeches by G.W.Bush, we say the speeches on terrorist attack in 2001 are similar, and the speeches on Iraq war are similar, which both makes sense.

# %%
# now focus on the speechs by nixon and the keywords

heatmapMatrixC = []

targetDocs = [x for x in speech_names if 'nixon' in x][-15:]

for tagOuter in targetDocs:
    column = []
    tagVec = speechD2V.docvecs[tagOuter].reshape(1, -1)
    for tagInner in keywords:
        column.append(sklearn.metrics.pairwise.cosine_similarity(tagVec, speechD2V.docvecs[tagInner].reshape(1, -1))[0][0])
    heatmapMatrixC.append(column)
heatmapMatrixC = np.array(heatmapMatrixC)

# %%
fig, ax = plt.subplots()
hmap = ax.pcolor(heatmapMatrixC, cmap='terrain')
cbar = plt.colorbar(hmap)

cbar.set_label('cosine similarity', rotation=270)
a = ax.set_xticks(np.arange(heatmapMatrixC.shape[1]) + 0.5, minor=False)
a = ax.set_yticks(np.arange(heatmapMatrixC.shape[0]) + 0.5, minor=False)

a = ax.set_xticklabels(keywords, minor=False, rotation=270)
a = ax.set_yticklabels(targetDocs, minor=False)

# %%
speechD2V.save('speechW2V')

# %% [markdown]
# ### Inference/Comment
#
# For the heatmap of Nixon's speeches and keywords, we say that the speeches on Vietnam war are all similar to the word "war", and the speeches on the Watergate issue is not similar to most of the topics, as it is a special case. The speech of resignment has the similar situation. The speech that is similar to most of the keywords is the speech on the ending of the Vietnam war. The reason may be that this speech covers the overall recovery plan for the country, so many topics are covered.

# %% [markdown]
# # Projection

# %% [markdown]
# We can also project word vectors to an arbitray semantic dimension. To demonstrate this possibility, let's first load a model trained with New York Times news articles.

# %%
nytimes_model = gensim.models.KeyedVectors.load_word2vec_format('../data/nytimes_cbow.reduced.txt')

# %% [markdown]
# First we can visualize with dimension reduction

# %%
#words to create dimensions
tnytTargetWords = ['man','him','he', 'woman', 'her', 'she', 'black','blacks','African', 'white', 'whites', 'Caucasian', 'rich', 'richer', 'richest', 'expensive', 'wealthy', 'poor', 'poorer', 'poorest', 'cheap', 'inexpensive']
#words we will be mapping
tnytTargetWords += ["doctor","lawyer","plumber","scientist","hairdresser", "nanny","carpenter","entrepreneur","musician","writer", "banker","poet","nurse", "steak", "bacon", "croissant", "cheesecake", "salad", "cheeseburger", "vegetables", "beer", "wine", "pastry", "basketball", "baseball", "boxing", "softball", "volleyball", "tennis", "golf", "hockey", "soccer"]


wordsSubMatrix = []
for word in tnytTargetWords:
    wordsSubMatrix.append(nytimes_model[word])
wordsSubMatrix = np.array(wordsSubMatrix)
#wordsSubMatrix

# %%
pcaWordsNYT = sklearn.decomposition.PCA(n_components = 50).fit(wordsSubMatrix)
reducedPCA_dataNYT = pcaWordsNYT.transform(wordsSubMatrix)
#T-SNE is theoretically better, but you should experiment
tsneWordsNYT = sklearn.manifold.TSNE(n_components = 2).fit_transform(reducedPCA_dataNYT)

# %%
fig = plt.figure(figsize = (20,12))
ax = fig.add_subplot(111)
ax.set_frame_on(False)
plt.scatter(tsneWordsNYT[:, 0], tsneWordsNYT[:, 1], alpha = 0) #Making the points invisible
for i, word in enumerate(tnytTargetWords):
    ax.annotate(word, (tsneWordsNYT[:, 0][i],tsneWordsNYT[:, 1][i]), size =  50 * (len(tnytTargetWords) - i) / len(tnytTargetWords))
plt.xticks(())
plt.yticks(())
plt.show()

# %% [markdown]
# Define some convenient functions for getting dimensions.

# %%
def normalize(vector):
    normalized_vector = vector / np.linalg.norm(vector)
    return normalized_vector

def dimension(model, positives, negatives):
    diff = sum([normalize(model[x]) for x in positives]) - sum([normalize(model[y]) for y in negatives])
    return diff

# %% [markdown]
# Let's calculate three dimensions: gender, race, and class.

# %%
Gender = dimension(nytimes_model, ['man','him','he'], ['woman', 'her', 'she'])
Race = dimension(nytimes_model, ['black','blacks','African'], ['white', 'whites', 'Caucasian'])
Class = dimension(nytimes_model, ['rich', 'richer', 'richest', 'expensive', 'wealthy'], ['poor', 'poorer', 'poorest', 'cheap', 'inexpensive'])

# %% [markdown]
# Here we have some words.

# %%
Occupations = ["doctor","lawyer","plumber","scientist","hairdresser", "nanny","carpenter","entrepreneur","musician","writer", "banker","poet","nurse"]

Foods = ["steak", "bacon", "croissant", "cheesecake", "salad", "cheeseburger", "vegetables", "beer", "wine", "pastry"]

Sports  = ["basketball", "baseball", "boxing", "softball", "volleyball", "tennis", "golf", "hockey", "soccer"]

# %% [markdown]
# Define a function to project words in a word list to each of the three dimensions.

# %%
def makeDF(model, word_list):
    g = []
    r = []
    c = []
    for word in word_list:
        g.append(sklearn.metrics.pairwise.cosine_similarity(nytimes_model[word].reshape(1,-1), Gender.reshape(1,-1))[0][0])
        r.append(sklearn.metrics.pairwise.cosine_similarity(nytimes_model[word].reshape(1,-1), Race.reshape(1,-1))[0][0])
        c.append(sklearn.metrics.pairwise.cosine_similarity(nytimes_model[word].reshape(1,-1), Class.reshape(1,-1))[0][0])
    df = pandas.DataFrame({'gender': g, 'race': r, 'class': c}, index = word_list)
    return df

# %% [markdown]
# Get the projections.

# %%
OCCdf = makeDF(nytimes_model, Occupations) 
Fooddf = makeDF(nytimes_model, Foods)
Sportsdf = makeDF(nytimes_model, Sports)

# %% [markdown]
# Define some useful functions for plotting.

# %%
def Coloring(Series):
    x = Series.values
    y = x-x.min()
    z = y/y.max()
    c = list(plt.cm.rainbow(z))
    return c

def PlotDimension(ax,df, dim):
    ax.set_frame_on(False)
    ax.set_title(dim, fontsize = 20)
    colors = Coloring(df[dim])
    for i, word in enumerate(df.index):
        ax.annotate(word, (0, df[dim][i]), color = colors[i], alpha = 0.6, fontsize = 12)
    MaxY = df[dim].max()
    MinY = df[dim].min()
    plt.ylim(MinY,MaxY)
    plt.yticks(())
    plt.xticks(())

# %% [markdown]
# Plot the occupational words in each of the three dimensions.

# %%
fig = plt.figure(figsize = (12,4))
ax1 = fig.add_subplot(131)
PlotDimension(ax1, OCCdf, 'gender')
ax2 = fig.add_subplot(132)
PlotDimension(ax2, OCCdf, 'race')
ax3 = fig.add_subplot(133)
PlotDimension(ax3, OCCdf, 'class')
plt.show()

# %% [markdown]
# Foods:

# %%
fig = plt.figure(figsize = (12,4))
ax1 = fig.add_subplot(131)
PlotDimension(ax1, Fooddf, 'gender')
ax2 = fig.add_subplot(132)
PlotDimension(ax2, Fooddf, 'race')
ax3 = fig.add_subplot(133)
PlotDimension(ax3, Fooddf, 'class')
plt.show()

# %% [markdown]
# Sports:

# %%
fig = plt.figure(figsize = (12,4))
ax1 = fig.add_subplot(131)
PlotDimension(ax1, Sportsdf, 'gender')
ax2 = fig.add_subplot(132)
PlotDimension(ax2, Sportsdf, 'race')
ax3 = fig.add_subplot(133)
PlotDimension(ax3, Sportsdf, 'class')
plt.show()

# %% [markdown]
# ## <span style="color:red">*Exercise 3*</span>
#
# <span style="color:red">Construct cells immediately below this that embed documents related to your final project, then generate meaningful semantic dimensions based on your theoretical understanding of the semantic space (i.e., by subtracting semantically opposite word vectors) and project another set of word vectors onto those dimensions. Interpret the meaning of these projections for your analysis. Which of the dimensions you analyze explain the most variation in the projection of your words and why?
#
# <span style="color:red">***Stretch***: Average together multiple antonym pairs to create robust semantic dimensions. How do word projections on these robust dimensions differ from single-pair dimensions?

# %%
# redo the model

speechW2V = gensim.models.word2vec.Word2Vec(speech_df['normalized_sents'].sum())

# %%
# set four dimensions: gender, race, class and ideology (categories of each dimension are shown in below)

def normalize(vector):
    normalized_vector = vector / np.linalg.norm(vector)
    return normalized_vector

def dimension(model, positives, negatives):
    diff = sum([normalize(model[x]) for x in positives]) - sum([normalize(model[y]) for y in negatives])
    return diff

Gender = dimension(speechW2V, ['man','men'], ['woman','women'])

Race = dimension(speechW2V, ['white', 'whites'], ['black','blacks','african'])

Class = dimension(speechW2V, ['rich', 'richer', 'richest', 'wealthy'], 
                             ['poor', 'poorer', 'poorest', 'cheap'])

Ideology = dimension(speechW2V, ['republican','republicans','conservative'],
                                ['liberal','democrat','democratic'])

# for the mapping words, I mainly use the names of president, some typical occupations, and some countries' name

Occupations = ["doctor","lawyer", "scientist",'usher','farmer',
               "entrepreneur","writer", "banker","poet","nurse", "politician",
               'worker', 'driver','professor','soldier','diplomat']

Names  = ['obama','bush', 'clinton','kennedy','carter','eisenhower','ford','nixon','roosevelt','reagan','truman','johnson']

Countries = ['china','america','canada','brazil','russia','japan','korea','vietnam','iraq','syria','iran','india','australia','britain','france','germany','congo','kenya','libya']

# get the list of target words

speechTargetWords = ['man','men','woman','women', 'black','blacks','african', 
                   'white', 'whites', 'rich', 'richer', 'richest', 
                   'wealthy', 'poor', 'poorer', 'poorest', 'cheap','republican','republicans','conservative',
                  'liberal', 'democrat','democratic']

speechTargetWords += Occupations + Names + Countries

# %%
wordsSubMatrix = []
for word in speechTargetWords:
    wordsSubMatrix.append(speechW2V[word])
wordsSubMatrix = np.array(wordsSubMatrix)
#wordsSubMatrix

# %%
pcaWords_speech = sklearn.decomposition.PCA(n_components = 50).fit(wordsSubMatrix)
reducedPCA_data_speech = pcaWords_speech.transform(wordsSubMatrix)
#T-SNE is theoretically better, but you should experiment
tsneWords_speech = sklearn.manifold.TSNE(n_components = 2).fit_transform(reducedPCA_data_speech)

# %%
# plot the target words

fig = plt.figure(figsize = (20,12))
ax = fig.add_subplot(111)
ax.set_frame_on(False)
plt.scatter(tsneWords_speech[:, 0], tsneWords_speech[:, 1], alpha = 0) #Making the points invisible
for i, word in enumerate(speechTargetWords):
    ax.annotate(word, (tsneWords_speech[:, 0][i],tsneWords_speech[:, 1][i]), size =  50 * (len(speechTargetWords) - i) / len(speechTargetWords))
plt.xticks(())
plt.yticks(())
plt.show()

# %%
# define the func for projection

def makeDF(model, word_list):
    g = []
    r = []
    c = []
    ideo=[]
    for word in word_list:
        
        g.append(sklearn.metrics.pairwise.cosine_similarity(speechW2V[word].reshape(1,-1), Gender.reshape(1,-1))[0][0])
        r.append(sklearn.metrics.pairwise.cosine_similarity(speechW2V[word].reshape(1,-1), Race.reshape(1,-1))[0][0])
        c.append(sklearn.metrics.pairwise.cosine_similarity(speechW2V[word].reshape(1,-1), Class.reshape(1,-1))[0][0])
        ideo.append(sklearn.metrics.pairwise.cosine_similarity(speechW2V[word].reshape(1,-1), Ideology.reshape(1,-1))[0][0])

    df = pandas.DataFrame({'gender': g, 'race': r, 'class': c,'ideology': ideo}, index = word_list)
    return df

# %%
OCCdf_speech = makeDF(speechW2V, Occupations) 
NAMEdf_speech = makeDF(speechW2V, Names)
COUNdf_speech = makeDF(speechW2V, Countries)

# %%
# plotting prepare

def Coloring(Series):
    x = Series.values
    y = x-x.min()
    z = y/y.max()
    c = list(plt.cm.rainbow(z))
    return c

def PlotDimension(ax,df, dim):
    ax.set_frame_on(False)
    ax.set_title(dim, fontsize = 20)
    colors = Coloring(df[dim])
    for i, word in enumerate(df.index):
        ax.annotate(word, (0, df[dim][i]), color = colors[i], alpha = 0.6, fontsize = 18)
    MaxY = df[dim].max()
    MinY = df[dim].min()
    plt.ylim(MinY,MaxY)
    plt.yticks(())
    plt.xticks(())

# %%
# plot occupation words

fig = plt.figure(figsize = (15,12))
ax1 = fig.add_subplot(141)
PlotDimension(ax1, OCCdf_speech, 'gender')
ax2 = fig.add_subplot(142)
PlotDimension(ax2, OCCdf_speech, 'race')
ax3 = fig.add_subplot(143)
PlotDimension(ax3, OCCdf_speech, 'class')
ax4 = fig.add_subplot(144)
PlotDimension(ax4, OCCdf_speech, 'ideology')
plt.show()

# %% [markdown]
# ### Inference/Comment
#
# It identifies the patterns of the occupations. For the dimensions, the "gender" generally explains the variation, as soldier and diplomat are more "male", but it is interesting that the "politican" is more "female", as well as the doctors.
#
# The "race" also generally identifies not bad, as often the diplomats and lawyers are white, but it sounds counter-intuitive for the banker to be black at the bottom.
#
# The "class" identifies not good, like the usher is in high class, but the doctor is in low.
#
# The "ideology" may also not good, as I assume that the doctor and professors may be more liberal, but not conservative.

# %%
# plot president names

fig = plt.figure(figsize = (15,12))
ax1 = fig.add_subplot(141)
PlotDimension(ax1, NAMEdf_speech, 'gender')
ax2 = fig.add_subplot(142)
PlotDimension(ax2, NAMEdf_speech, 'race')
ax3 = fig.add_subplot(143)
PlotDimension(ax3, NAMEdf_speech, 'class')
ax4 = fig.add_subplot(144)
PlotDimension(ax4, NAMEdf_speech, 'ideology')
plt.show()

# %% [markdown]
# ### Inference/Comment
#
# It is the most interesting part in this exercise. We find Truman and Roosevelt more "man", maybe due to that they are presidents around WWII, so their speeches are more "male". Also we find Clinton and Bush more "female", maybe due to their personal patterns, I'm not sure.
#
# The "race" makes sense, as Obama is at the bottom, and he is the only African American president.
#
# The "class" actually doesn't make much sense, as the kennedy family and bush family should be quite big and influential, but they are not in the high class.
#
# For "ideology", it extracts the presidents from Democrat well, as Obama, Carter, Truman, Johnson are all Democrats. It also to some degrees extracts Republican presidents, like Eisenhower, Reagan, Nixon, Ford, and Bush. However, there are three outliners, Kennedy, Clinton and Roosevelt are marked as Republican. I guess that maybe they could be considered as moderate Democrat, but further potilical and historical background should be explored.

# %%
# plot country names

fig = plt.figure(figsize = (15,12))
ax1 = fig.add_subplot(141)
PlotDimension(ax1, COUNdf_speech, 'gender')
ax2 = fig.add_subplot(142)
PlotDimension(ax2, COUNdf_speech, 'race')
ax3 = fig.add_subplot(143)
PlotDimension(ax3, COUNdf_speech, 'class')
ax4 = fig.add_subplot(144)
PlotDimension(ax4, COUNdf_speech, 'ideology')
plt.show()

# %% [markdown]
# ### Inference/Comment
#
# It is also an interesting part. We see that USA, Korea, Germany and Iraq are considered more "man", while France, Canada, Brazil, Kenya, Libya and Congo are more "woman". It makes senses, as USA, Germany and Iraq have engaged many conflicts and wars. For France and Canada, we often consider them as elegant or charm, and for African countries, we often consider them as weak.
#
# The "race" identifies not bad, as many western countries on the top (white), and many African countries on the bottom (black).
#
# For "class", many developed countries on the top (interesting to have China here), and developing countries on the bottom.
#
# It may hard to find the ideology of countries, but we find that the richer the country (or higher class the country), the more liberal they will be.
#
# #### Overall comment
#
# Due to the limitations of the corpus, the accuracy of dimensions is not that good, since the categories in each dimension are quite limited (e.g. the corpus doesn't "female", "he", "she", so I just use "men,man, woman and women"). However, overall we can extract some patterns from the speech, and "gender" dimension may make most sense, while other three in general are also not quite bad.

# %% [markdown]
# # The Score Function
#
# The score function is a simple calculation developed by [Matt Taddy](https://arxiv.org/pdf/1504.07295.pdf) to calculate the likelihood that a given text would have been generated by a word-embedding model by summing the inner product between each pair of the text's word vectors. This relies on a few data files that are not in the git repo due to their size please download and unzip [this](https://github.com/Computational-Content-Analysis-2018/Upcoming/raw/master/data/supplement.zip) (472MB) file in the data directory.
#
# Here, we explore this using a model trained with millions of resumes from the CareerBuilder website (we can't share the private resumes...but we can share a model built with them :-):

# %%
resume_model  = gensim.models.word2vec.Word2Vec.load('/Users/timqzhang/Desktop/UChicago/MACSS_Spring_2020/content_local/supplement/resumeAll.model')

# %% [markdown]
# We can examine the vacabularies of this model by building a word-index map:

# %%
vocab = resume_model.wv.index2word

# %% [markdown]
# Let's just load the sample and take a look at it. The sentences in each job description are already tokenized and normalized.

# %%
sampleDF = pandas.read_csv('/Users/timqzhang/Desktop/UChicago/MACSS_Spring_2020/content_local/supplement//SampleJobAds.csv', index_col = False)
#We need to convert the last couple columns from strings to lists
sampleDF['tokenized_sents'] = sampleDF['tokenized_sents'].apply(lambda x: eval(x))
sampleDF['normalized_sents'] = sampleDF['normalized_sents'].apply(lambda x: eval(x))
sampleDF
# Out:
#     Unnamed: 0 hiringOrganization_organizationName  \
# 0       158844       Golfsmith International, Inc.
# 1       257645                               Intel
# 2       107875                    Florida Hospital
# 3       202394                Hitachi Data Systems
# 4       109675           Footprint Retail Services
# ..         ...                                 ...
# 95      157791                       Golden Living
# 96      119835                            GameStop
# 97      285609                          Jewel-Osco
# 98       89260                     Express Scripts
# 99      280096                            JCPenney
#
#                                        jobDescription  \
# 0   "Sales Associate Tracking Code 220425-971 Job ...
# 1   For PHY system engineering team within the Wir...
# 2   *RN Medical Oncology PCU Orlando - Nights* Flo...
# 3   Title: Specialist Sales Account Representative...
# 4   **Footprint Retail Services** **Job Descriptio...
# ...

# %% [markdown]
# Let's define a function to calculate the likelihood of each job description. The idea is borrowed from [Matt Taddy](https://github.com/RaRe-Technologies/gensim/blob/develop/docs/notebooks/deepir.ipynb), who shows how a document can be characterized as the inner product of the distance between its words. In other words, this analysis will show which job ads are most likely to find an appropriate pool of workers in the resume bank that generated our word embedding.

# %%
def adprob(ad, model):
    sen_scores = model.score(ad, len(ad))
    ad_score = sen_scores.mean()
    return ad_score

# %% [markdown]
# Let's apply this function to every job description.

# %%
sampleDF['likelihood'] = sampleDF['normalized_sents'].apply(lambda x: adprob(x, resume_model))

# %% [markdown]
# Let's take a look at the top 5 job descriptions that have the highest likelihood.

# %%
for ad in sampleDF.sort_values(by = 'likelihood', ascending = False)['jobDescription'][:5]:
    print (ad + '\n\n')
# Out:
# Project Engineering including below jobs: 1. Hardware designing of DCS 2. Software configurations, programming, testing of DCS/PLC 3. Testing and FAT 4. Installation and commissioning. 5. Material ordering, approvals of datasheets. 6. HSE compliance as per HSE directives of HON. BE / B. Tech - Instrumentation / Control / Electronics. **Job:** **Engineering* **Title:** *Systems Engineer* **Location:** *IND-MH-Pune* **Requisition ID:** *00302235*
#
#
# Like talking on the phone? Enjoy giving great customer service? Use those skills while working flexible,part time hours.
#
#
# *# Positions:* 2 *Location:* US - UT - Orem *Category:* Engineering
#
#
# Title: Respiratory Therapy, Intern Location: XX-XX-XX
#
#
# Title: Position Opening at Illinois Wesleyan University Location: US-IL-Bloomington

# %% [markdown]
# Let's take a look at the bottom 5 job descriptions that have the lowest likelihood to be matched by the resumes.

# %%
for ad in sampleDF.sort_values(by = 'likelihood')['jobDescription'][:5]:
    print (ad + '\n\n')
# Out:
# Title: Contract Svc Admin Location: United States\-Michigan\-Caledonia Other Locations: JOB SUMMARY: ESSENTIAL DUTIES AND RESPONSIBILITIES: _ Other duties may be assigned:_ Prepare GPO rebate data for upload into STARR system oEnsure accurate data loads oProcess data into required reports oEnsure that GPOs are paid accurately and timely Prepare Sales Tracing data for upload into STARR system oEnsure accurate data loads oProcess data into required reports Prepare Rebate data for upload into STARR system oEnsure accurate data loads oProcess data into required reports oEnsure that distributors are accurately taking rebates against open invoices Manage work flow throughout the sales contracting process Ensure compliance with contract policies and performance requirements Assist in the preparation of charts and sales reports and analytics for customers and Management oQuarterly Reports oSales Tracing Answers customers and internal sale/customer service staff questions regarding pricing Ma
# ...

# %% [markdown]
# We can do the same for phrases corresponding to job skills.

# %%
adprob([["python", "programming"]], resume_model)
# Out:
# -14.355247

# %%
adprob([["julia", "programming"]], resume_model)
# Out:
# -33.427353

# %% [markdown]
# Basic programming appears to be more likely in this pool of resumes than python programming.
#
# We can also do some simple statistics. Unfortunately, we don't have a large sample here. Nevertheless, let's first look at the mean likelihood score of each hiring organization. Some organizations will do well to hire on CareerBuilder...while others will not.

# %%
sampleDF.groupby("hiringOrganization_organizationName")[['likelihood']].mean().sort_values('likelihood', ascending = False)
# Out:
#                                       likelihood
# hiringOrganization_organizationName
# Honeywell                             -25.974749
# Legrand North America                 -40.500500
# Franciscan St. Eilzabeth Health       -43.167206
# Illinois Wesleyan University          -52.681591
# Gold's Gym                            -75.230896
# ...                                          ...
# G6 Hospitality                       -468.545807
# Epic Health Services                 -527.781067
# Kforce                               -762.142422
# Dollar Tree                          -818.945801
# Hill-Rom                            -2675.631592
#
# [67 rows x 1 columns]

# %% [markdown]
# We can also look at the mean likelihood of each state.

# %%
sampleDF.groupby("jobLocation_address_region")[['likelihood']].mean().sort_values('likelihood', ascending = False)
# Out:
#                              likelihood
# jobLocation_address_region
# Utah                         -40.500500
# Montana                      -63.730721
# Connecticut                  -67.623466
# Kansas                       -85.259682
# Tennessee                    -93.188822
# Illinois                     -93.989101
# New Hampshire                -94.109772
# Georgia                     -102.271820
# South Carolina              -103.527328
# North Carolina              -108.747134
# Ohio                        -122.494473
# Louisiana                   -138.063202
# Florida                     -147.725601
# California                  -147.850291
# Maryland                    -151.947347
# Arizona                     -154.733734
# Minnesota                   -159.437958
# Virginia                    -160.932640
# Wisconsin                   -170.760437
# Missouri                    -177.804581
# South Dakota                -180.824776
# Nebraska                    -194.792297
# ...

# %% [markdown]
# You would increase the sample size if you want to do a more serious study.
#
# ## <span style="color:red">*Exercise 4a*</span>
#
# <span style="color:red">**Do only 4a or 4b.** Construct cells immediately below this that calculate the scores for a small sample of documents from outside your corpus to identify which are *closest* to your corpus. Then calculate the scores for a few phrases or sentences to identify the ones most likely to have appeared in your corpus. Interrogate patterns associated with these document/phrase scores (e.g., which companies produced job ads most or least likely to find jobseekers in the resume corpus?) What do these patterns suggest about the boundaries of your corpus?

# %% [markdown]
# # Linguistic Change or Difference
#
# Below is code that aligns the dimensions of multiple embeddings arrayed over time or some other dimension and allow identification of semantic chanage as the word vectors change their loadings for focal words. This code comes from the approach piloted at Stanford by William Hamilton, Daniel Jurafsky and Jure Lescovec [here](https://arxiv.org/pdf/1605.09096.pdf).

# %%
import copy

# %%
def calc_syn0norm(model):
    """since syn0norm is now depricated"""
    return (model.wv.syn0 / np.sqrt((model.wv.syn0 ** 2).sum(-1))[..., np.newaxis]).astype(np.float32)

def smart_procrustes_align_gensim(base_embed, other_embed, words=None):
    """Procrustes align two gensim word2vec models (to allow for comparison between same word across models).
    Code ported from HistWords <https://github.com/williamleif/histwords> by William Hamilton <wleif@stanford.edu>.
    (With help from William. Thank you!)
    First, intersect the vocabularies (see `intersection_align_gensim` documentation).
    Then do the alignment on the other_embed model.
    Replace the other_embed model's syn0 and syn0norm numpy matrices with the aligned version.
    Return other_embed.
    If `words` is set, intersect the two models' vocabulary with the vocabulary in words (see `intersection_align_gensim` documentation).
    """
    base_embed = copy.copy(base_embed)
    other_embed = copy.copy(other_embed)
    # make sure vocabulary and indices are aligned
    in_base_embed, in_other_embed = intersection_align_gensim(base_embed, other_embed, words=words)

    # get the embedding matrices
    base_vecs = calc_syn0norm(in_base_embed)
    other_vecs = calc_syn0norm(in_other_embed)

    # just a matrix dot product with numpy
    m = other_vecs.T.dot(base_vecs) 
        
    # SVD method from numpy
    u, _, v = np.linalg.svd(m)
    # another matrix operation
    ortho = u.dot(v) 
    # Replace original array with modified one
    # i.e. multiplying the embedding matrix (syn0norm)by "ortho"
    other_embed.wv.syn0norm = other_embed.wv.syn0 = (calc_syn0norm(other_embed)).dot(ortho)
    return other_embed
    
def intersection_align_gensim(m1,m2, words=None):
    """
    Intersect two gensim word2vec models, m1 and m2.
    Only the shared vocabulary between them is kept.
    If 'words' is set (as list or set), then the vocabulary is intersected with this list as well.
    Indices are re-organized from 0..N in order of descending frequency (=sum of counts from both m1 and m2).
    These indices correspond to the new syn0 and syn0norm objects in both gensim models:
        -- so that Row 0 of m1.syn0 will be for the same word as Row 0 of m2.syn0
        -- you can find the index of any word on the .index2word list: model.index2word.index(word) => 2
    The .vocab dictionary is also updated for each model, preserving the count but updating the index.
    """

    # Get the vocab for each model
    vocab_m1 = set(m1.wv.vocab.keys())
    vocab_m2 = set(m2.wv.vocab.keys())

    # Find the common vocabulary
    common_vocab = vocab_m1&vocab_m2
    if words: common_vocab&=set(words)

    # If no alignment necessary because vocab is identical...
    if not vocab_m1-common_vocab and not vocab_m2-common_vocab:
        return (m1,m2)

    # Otherwise sort by frequency (summed for both)
    common_vocab = list(common_vocab)
    common_vocab.sort(key=lambda w: m1.wv.vocab[w].count + m2.wv.vocab[w].count,reverse=True)

    # Then for each model...
    for m in [m1,m2]:
        # Replace old syn0norm array with new one (with common vocab)
        indices = [m.wv.vocab[w].index for w in common_vocab]
        old_arr = calc_syn0norm(m)
        new_arr = np.array([old_arr[index] for index in indices])
        m.wv.syn0norm = m.wv.syn0 = new_arr

        # Replace old vocab dictionary with new one (with common vocab)
        # and old index2word with new one
        m.index2word = common_vocab
        old_vocab = m.wv.vocab
        new_vocab = {}
        for new_index,word in enumerate(common_vocab):
            old_vocab_obj=old_vocab[word]
            new_vocab[word] = gensim.models.word2vec.Vocab(index=new_index, count=old_vocab_obj.count)
        m.wv.vocab = new_vocab

    return (m1,m2)

# %% [markdown]
# In order to explore this, let's get some data that follows a time trend. We'll look at conference proceedings from the American Society for Clinical Oncologists.

# %%
ascoDF = pandas.read_csv("/Users/timqzhang/Desktop/UChicago/MACSS_Spring_2020/content_local/supplement/ASCO_abstracts.csv", index_col=0)

# %% [markdown]
# Prepare for wor2vec:

# %%
ascoDF['tokenized_sents'] = ascoDF['Body'].apply(lambda x: [lucem_illud_2020.word_tokenize(s) for s in lucem_illud_2020.sent_tokenize(x)])
ascoDF['normalized_sents'] = ascoDF['tokenized_sents'].apply(lambda x: [lucem_illud_2020.normalizeTokens(s) for s in x])

# %%
ascoDF
# Out:
#        Year                                   AbstractCategory  \
# 0      1995                                        Lung Cancer
# 1      1995                                      Breast Cancer
# 2      1995                                 Gynecologic Cancer
# 3      1995                                        Lung Cancer
# 4      1995                      Other Gastrointestinal Cancer
# ...     ...                                                ...
# 62568  2011  Lung Cancer - Local-Regional and Adjuvant Ther...
# 62576  2011                          Patient and Survivor Care
# 62577  2011  Developmental TherapeuticsÑExperimental Therap...
# 62585  2011                               Genitourinary Cancer
# 62604  2011               Gastrointestinal (Colorectal) Cancer
#
#                                                    Title      FirstAuthor  \
# 0      Treatment of non-small cell lung cancer with c...  GP Stathopoulos
# ...

# %% [markdown]
# We will be creating many embeddings so we have created this function to do most of the work. It creates two collections of embeddings, one the original and one the aligned.

# %%
def compareModels(df, category, text_column_name='normalized_sents', sort = True, embeddings_raw={}):
    """If you are using time as your category sorting is important"""
    if len(embeddings_raw) == 0:
        embeddings_raw = rawModels(df, category, text_column_name, sort)
    cats = sorted(set(df[category]))
    #These are much quicker
    embeddings_aligned = {}
    for catOuter in cats:
        embeddings_aligned[catOuter] = [embeddings_raw[catOuter]]
        for catInner in cats:
            embeddings_aligned[catOuter].append(smart_procrustes_align_gensim(embeddings_aligned[catOuter][-1], embeddings_raw[catInner]))
    return embeddings_raw, embeddings_aligned

# %%
def rawModels(df, category, text_column_name='normalized_sents', sort = True):
    embeddings_raw = {}
    cats = sorted(set(df[category]))
    for cat in cats:
        #This can take a while
        print("Embedding {}".format(cat), end = '\r')
        subsetDF = df[df[category] == cat]
        #You might want to change the W2V parameters
        embeddings_raw[cat] = gensim.models.word2vec.Word2Vec(subsetDF[text_column_name].sum())
    return embeddings_raw

# %% [markdown]
# Now we generate the models:

# %%
rawEmbeddings, comparedEmbeddings = compareModels(ascoDF, 'Year')
# Out:
# Embedding 2011

# %%
rawEmbeddings.keys()
# Out:
# dict_keys([1995, 1996, 1997, 1998, 1999, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011])

# %% [markdown]
# We need to compare them across all permutions so we will define another function to help, we will be using 1 - cosine similarity as that gives a more intitive range of 0-2 with low values meaning little change and high meaning lots of change.

# %%
def getDivergenceDF(word, embeddingsDict):
    dists = []
    cats = sorted(set(embeddingsDict.keys()))
    dists = {}
    print(word)
    for cat in cats:
        dists[cat] = []
        for embed in embeddingsDict[cat][1:]:
            dists[cat].append(np.abs(1 - sklearn.metrics.pairwise.cosine_similarity(np.expand_dims(embeddingsDict[cat][0][word], axis = 0),
                                                                             np.expand_dims(embed[word], axis = 0))[0,0]))
    return pandas.DataFrame(dists, index = cats)

# %% [markdown]
# Lets look at a couple words:

# %%
targetWord = 'breast'

pltDF = getDivergenceDF(targetWord, comparedEmbeddings)
fig, ax = plt.subplots(figsize = (10, 7))
seaborn.heatmap(pltDF, ax = ax, annot = False) #set annot True for a lot more information
ax.set_xlabel("Starting year")
ax.set_ylabel("Final year")
ax.set_ylabel("Final year")
ax.set_title("Yearly linguistic change for: '{}'".format(targetWord))
plt.show()
# Out:
# breast

# %%
targetWord = 'combination'

pltDF = getDivergenceDF(targetWord, comparedEmbeddings)
fig, ax = plt.subplots(figsize = (10, 7))
seaborn.heatmap(pltDF, ax = ax, annot = False) #set annot True for a lot more information
ax.set_xlabel("Starting year")
ax.set_ylabel("Final year")
ax.set_ylabel("Final year")
ax.set_title("Yearly linguistic change for: '{}'".format(targetWord))
plt.show()
# Out:
# combination

# %%
def findDiverence(word, embeddingsDict):
    cats = sorted(set(embeddingsDict.keys()))
    
    dists = []
    for embed in embeddingsDict[cats[0]][1:]:
        dists.append(1 - sklearn.metrics.pairwise.cosine_similarity(np.expand_dims(embeddingsDict[cats[0]][0][word], axis = 0), np.expand_dims(embed[word], axis = 0))[0,0])
    return sum(dists)

def findMostDivergent(embeddingsDict):
    words = []
    for embeds in embeddingsDict.values():
        for embed in embeds:
            words += list(embed.wv.vocab.keys())
    words = set(words)
    print("Found {} words to compare".format(len(words)))
    return sorted([(w, findDiverence(w, embeddingsDict)) for w in words], key = lambda x: x[1], reverse=True)

# %%
wordDivergences = findMostDivergent(comparedEmbeddings)
# Out:
# Found 1571 words to compare

# %% [markdown]
# The most divergent words are:

# %%
wordDivergences[:20]
# Out:
# [('n', 13.311919620260596),
#  ('ajcc', 13.295144721865654),
#  ('iv', 12.842569384723902),
#  ('dose', 12.830906189978123),
#  ('b', 12.802740089595318),
#  ('activity', 12.793256225064397),
#  ('efficacy', 12.788487065583467),
#  ('level', 12.766379091888666),
#  ('g', 12.711334474384785),
#  ('t', 12.681266754865646),
#  ('c', 12.62512554321438),
#  ('csf', 12.607977852225304),
#  ('p', 12.582295384258032),
#  ('grade', 12.532850926741958),
#  ('low', 12.523577367886901),
#  ('high', 12.489437462761998),
#  ('be', 12.486444569192827),
#  ('response', 12.482275106012821),
#  ('vs', 12.448853679001331),
#  ('=', 12.447082374244928)]

# %% [markdown]
# And the least:

# %%
wordDivergences[-20:]
# Out:
# [('discuss', 1.7681499123573303),
#  ('difficult', 1.758820354938507),
#  ('ensure', 1.718675434589386),
#  ('difficulty', 1.6920450925827026),
#  ('bias', 1.6916437149047852),
#  ('definition', 1.6782360672950745),
#  ('agreement', 1.6637114882469177),
#  ('traditional', 1.6441596746444702),
#  ('answer', 1.6094472408294678),
#  ('call', 1.5824307203292847),
#  ('particular', 1.5485907196998596),
#  ('insufficient', 1.4745405316352844),
#  ('simple', 1.4730886220932007),
#  ('widespread', 1.4423729181289673),
#  ('nature', 1.3633830547332764),
#  ('constitute', 1.3044564723968506),
#  ('special', 1.280178189277649),
#  ('uncertain', 1.1959339380264282),
#  ('situation', 1.1472293734550476),
#  ('view', 1.135632574558258)]

# %%
targetWord = wordDivergences[0][0]

pltDF = getDivergenceDF(targetWord, comparedEmbeddings)
fig, ax = plt.subplots(figsize = (10, 7))
seaborn.heatmap(pltDF, ax = ax, annot = False) #set annot True for a lot more information
ax.set_xlabel("Starting year")
ax.set_ylabel("Final year")
ax.set_ylabel("Final year")
ax.set_title("Yearly linguistic change for: '{}'".format(targetWord))
plt.show()
# Out:
# n

# %%
targetWord = wordDivergences[-1][0]

pltDF = getDivergenceDF(targetWord, comparedEmbeddings)
fig, ax = plt.subplots(figsize = (10, 7))
seaborn.heatmap(pltDF, ax = ax, annot = False) #set annot True for a lot more information
ax.set_xlabel("Starting year")
ax.set_ylabel("Final year")
ax.set_ylabel("Final year")
ax.set_title("Yearly linguistic change for: '{}'".format(targetWord))
plt.show()
# Out:
# view

# %% [markdown]
# ## COHA
#
# COHA is a historial dataset so it ends up being a good choice to try the same analysis we just did across three different time periods.
#
# We will be using the same data loading procedure as the last notebook, so go through the process to make sure you know what's going on.

# %%
corpora_address = "/Users/timqzhang/Desktop/UChicago/MACSS_Spring_2020/content_local/COHA"

# %%
coha_texts = lucem_illud_2020.loadDavies(corpora_address, return_raw=True)
# Out:
# text_1940s_bsw.zip
# text_1920s_gte.zip
# text_1900s_mse.zip
# text_1810s_kso.zip
# text_2000s_scc.zip
# text_1910s_jue.zip
# text_1890s_jsq.zip
# text_1870s_vuy.zip
# text_1840s_nsq.zip
# text_1860s_psi.zip
# text_1950s_ndz.zip
# text_1820s_jsi.zip
# text_1980s_bkk.zip
# text_1930s_bie.zip
# text_1960s_xus.zip
# text_1990s_bsj.zip
# text_1830s_bsu.zip
# text_1850s_jpr.zip
# text_1970s_jfy.zip
# text_1880s_azz.zip

# %% [markdown]
# Cool - let us now create our different epochs. This is an important step: I will be using the same 5 epochs I did in the DTM example, but you are recommended to play around with this. I will create a dataframe which logs the year and the genre.

# %%
coha_df = pandas.DataFrame(columns=["Year", "Genre", "Epoch", "normalized sents"])

# %%
for article in coha_texts:
    genre, year, id_ = article.split("_")

    year = int(year)
    
    if year > 1810 and year < 1880:
        epoch = 0
    if year >= 1880 and year < 1913:
        epoch = 1
    if year >= 1913 and year < 1950:
        epoch = 2
    if year >= 1950 and year < 1990:
        epoch = 3
    if year >= 1990:
        epoch = 4
    
    try:
        if len(coha_texts[article][2]) < 1500000:
            coha_df.loc[id_] = [year, genre, epoch, lucem_illud_2020.normalizeTokens(coha_texts[article][2].decode("utf-8"), lemma=False)]
    except TypeError:
        continue
    except IndexError:
        continue

# %% [markdown]
# We can now arrange our word embeddings by either year, genre, or epoch, and see how the words in each of those contexts change.

# %%
rawEmbeddings_epoch = rawModels(coha_df, 'Epoch', text_column_name='normalized sents')
# Out:
# Embedding 4

# %%
# rawEmbeddings_genre = rawModels(coha_df, 'Genre', text_column_name='normalized sents')

# %% [markdown]
# We now have the raw embeddings for epoch and genre. You can test out the previous analysis on words of your choice.

# %%
for epoch, embedding in enumerate(rawEmbeddings_epoch):
    model = rawEmbeddings_epoch[embedding]
    name = "embedding_epoch_" + str(epoch)
    model.save(name)

# %%
# for embedding in rawEmbeddings_genre:
#     model = rawEmbeddings_genre[embedding]
#     name = "embedding_genre_" + embedding
#     model.save(name)

# %%
from gensim.models import Word2Vec

# %%
def file_to_embeddings(address, kind):
    rawEmbeddings = {}
    for file in os.listdir(address):
        if "embedding_"+kind in file:
            e, kind_, kind_type = file.split("_")
            kind_type = eval(kind_type)
            rawEmbeddings[kind_type] = Word2Vec.load(file)
    return rawEmbeddings

# %%
# rawEmbeddings_genre_load = file_to_embeddings(".", "genre")

# %%
rawEmbeddings_epoch_load = file_to_embeddings(".", "epoch")

# %%
rawEmbeddings_epoch_load.keys()
# Out:
# dict_keys([0, 1, 4, 3, 2])

# %%
rawEmbeddings_epoch, compared_epoch = compareModels(coha_df, 'Epoch', text_column_name='normalized sents', embeddings_raw=rawEmbeddings_epoch_load)

# %%
# rawEmbeddings_genre, compared_genre = compareModels(coha_df, 'Genre', text_column_name='normalized sents', embeddings_raw=rawEmbeddings_genre_load)

# %% [markdown]
# You now have access to the epoch wise embeddings, and the code to train models genre wise (commented out).
# You can use the original embeddings, the compared embeddings and such to perform the analysis we did before.

# %% [markdown]
# ## <span style="color:red">*Exercise 4b*</span>
#
# <span style="color:red">**Do only 4a or 4b.** Construct cells immediately below this that align word embeddings over time or across domains/corpora. Interrogate the spaces that result and ask which words changed most and least over the entire period or between contexts/corpora. What does this reveal about the social game underlying your space?

# %%
# add a year column

year=[int(x.year) for x in list(speech_df['date'])]

speech_df['year']=year

# %%
speech_df
# Out:
#     president_name                                            context  \
# 92     fdroosevelt                            First Inaugural Address
# 88     fdroosevelt             Fireside Chat 1: On the Banking Crisis
# 95     fdroosevelt  Fireside Chat 2: On Progress During the First ...
# 81     fdroosevelt  Fireside Chat 3: On the National Recovery Admi...
# 84     fdroosevelt              Fireside Chat 4: On Economic Progress
# ..             ...                                                ...
# 173          obama                    2015 State of the Union Address
# 172          obama  Remarks in Eulogy for the Honorable Reverend C...
# 132          obama                    2016 State of the Union Address
# 171          obama                      Remarks to the People of Cuba
# 131          obama         Commencement Address at Rutgers University
#
#           date                                               text  \
# ...

# %%
def compareModels(df, category, text_column_name='normalized_sents', sort = True, embeddings_raw={}):
    """If you are using time as your category sorting is important"""
    if len(embeddings_raw) == 0:
        embeddings_raw = rawModels(df, category, text_column_name, sort)
    cats = sorted(set(df[category]))
    #These are much quicker
    embeddings_r_new = copy.deepcopy(embeddings_raw)
    embeddings_aligned = {}
    for catOuter in cats:
        #print([embeddings_r_new[catOuter]])
        embeddings_aligned[catOuter] = [embeddings_r_new[catOuter]]
        for catInner in cats:
            embeddings_aligned[catOuter].append(smart_procrustes_align_gensim(embeddings_aligned[catOuter][-1], embeddings_r_new[catInner]))
    
    return embeddings_raw, embeddings_aligned

# %%
def rawModels(df, category, text_column_name='normalized_sents', sort = True):
    embeddings_raw = {}
    cats = sorted(set(df[category]))
    for cat in cats:
        #This can take a while
        print("Embedding {}".format(cat), end = '\r')
        subsetDF = df[df[category] == cat]
        #print(subsetDF)
        #You might want to change the W2V parameters
        embeddings_raw[cat] = gensim.models.word2vec.Word2Vec(subsetDF[text_column_name].sum())
    return embeddings_raw

# %%
def getDivergenceDF(word, embeddingsDict):
    dists = []
    cats = sorted(set(embeddingsDict.keys()))
    dists = {}
    print(word)
    for cat in cats:
        dists[cat] = []
        for embed in embeddingsDict[cat][1:]:
            dists[cat].append(np.abs(1 - sklearn.metrics.pairwise.cosine_similarity(np.expand_dims(embeddingsDict[cat][0][word], axis = 0),
                                                                             np.expand_dims(embed[word], axis = 0))[0,0]))
    return pandas.DataFrame(dists, index = cats)

# %%
def findDiverence(word, embeddingsDict):
    cats = sorted(set(embeddingsDict.keys()))
    
    dists = []
    for embed in embeddingsDict[cats[0]][1:]:
        dists.append(1 - sklearn.metrics.pairwise.cosine_similarity(np.expand_dims(embeddingsDict[cats[0]][0][word], axis = 0), np.expand_dims(embed[word], axis = 0))[0,0])
    return sum(dists)

def findMostDivergent(embeddingsDict):
    words = []
    for embeds in embeddingsDict.values():
        for embed in embeds:
            words += list(embed.wv.vocab.keys())
    words = set(words)
    print("Found {} words to compare".format(len(words)))
    return sorted([(w, findDiverence(w, embeddingsDict)) for w in words], key = lambda x: x[1], reverse=True)

# %%
# as there are almost no word to compare if we get the entire period, I choose the starting point as 1960.

rawEmbeddings_all, comparedEmbeddings_all = compareModels(speech_df[speech_df['year']>=1960], 'year')
# Out:
# Embedding 2016

# %%
rawEmbeddings_all.keys()
# Out:
# dict_keys([1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016])

# %%
# check how mayn words to compare

wordDivergences_all = findMostDivergent(comparedEmbeddings_all)
# Out:
# Found 9 words to compare

# %%
# only 9 words...well, let's see what are they

wordDivergences_all
# Out:
# [('time', 50.22560120932758),
#  ('america', 48.083420876413584),
#  ('people', 44.36544181779027),
#  ('years', 42.583519691601396),
#  ('world', 39.79505021870136),
#  ('new', 38.371968898922205),
#  ('american', 38.016364661976695),
#  ('nation', 37.66482841223478),
#  ('future', 37.384432554244995)]

# %%
# we could check people and future
   
targetWord = 'people'
pltDF = getDivergenceDF(targetWord, comparedEmbeddings_all)
fig, ax = plt.subplots(figsize = (10, 7))
seaborn.heatmap(pltDF, ax = ax, annot = False) #set annot True for a lot more information
ax.set_xlabel("Starting year")
ax.set_ylabel("Final year")
ax.set_title("Yearly linguistic change for: '{}'".format(targetWord))
plt.show()
# Out:
# people

# %%
# further check on "people"

# get the freq of "people" by presidents

people_dict={}
for index,row in speech_df.iterrows():
    if row['president_name'] not in people_dict.keys():
            people_dict[row['president_name']]=0
            
    for text in row['normalized_sents']:
        if 'people' in text or 'People' in text:
            for word in text:
                if word=='people' or word=='People':
                    people_dict[row['president_name']]+=1

# %%
# set the name list by time

pres_name=['fdroosevelt','truman','eisenhower','kennedy',
          'lbjohnson','nixon','ford','carter','reagan','bush',
          'clinton','gwbush','obama']

pres_name_p=['fdroosevelt(D)','truman(D)','eisenhower(R)','kennedy(D)',
          'lbjohnson(D)','nixon(R)','ford(R)','carter(D)','reagan(R)','bush(R)',
          'clinton(D)','gwbush(R)','obama(D)']

people_num=[]

for name in pre_name:
    people_num.append(people_dict[name])

# plot the raw freq

plt.figure(figsize=(15,8))
plt.plot(pre_name_p,people_num)
plt.xticks(fontsize=15,rotation=90)
plt.yticks(fontsize=15)
plt.ylabel('raw frequency of "people"',fontsize=15)
plt.xlabel('president with party by time',fontsize=15)
# Out:
# Text(0.5, 0, 'president with party by time')

# %%
# normalize the freq: freq/speech_num for each president

speech_num_df=speech_df['president_name'].value_counts()

speech_num=[]

for name in pres_name:
    speech_num.append(speech_num_df[name])

normalized_people_num=[]

for i,name in enumerate(pres_name):
    normalized_people_num.append(round(people_num[i]/speech_num[i],2))

# %%
# plot the normalized freq

plt.figure(figsize=(15,8))
plt.plot(pre_name_p,normalized_people_num)
plt.xticks(fontsize=15,rotation=90)
plt.yticks(fontsize=15)
plt.ylabel('normalized frequency of "people"',fontsize=15)
plt.xlabel('president with party by time',fontsize=15)
# Out:
# Text(0.5, 0, 'president with party by time')

# %%
# we then check future
   
targetWord = 'future'
pltDF = getDivergenceDF(targetWord, comparedEmbeddings_all)
fig, ax = plt.subplots(figsize = (10, 7))
seaborn.heatmap(pltDF, ax = ax, annot = False) #set annot True for a lot more information
ax.set_xlabel("Starting year")
ax.set_ylabel("Final year")
ax.set_title("Yearly linguistic change for: '{}'".format(targetWord))
plt.show()
# Out:
# future

# %% [markdown]
# ### Inference/Comment
#
# It seems that the time series of "people" doesn't have many patterns, but it shows some cycles, as the black blocks appears from time to time. After the comparison of the term period of presidents, it is quite interesting that there is a cycled linguistic shift on "people" between Democrat and Republican presidents when they alternate from term to term. Wow! However, when we further check the frequency of "people", especially the normalized frequency, we see the trend is weakened, but still strong from Bush Obama.
#
# For "future", we see clear blocks. We see clear linguistic shift on "future" at the time period of 1961-1974,1980-1982,1998-2010. These three periods all have big events, namely the Vietnam War, second oil crisis, and the terrorism attack at September 11, 2001 and the Iraq war. Therefore, such a lignuistic shift indicates the president's change of attitudes in the speech towards future. There is a change when the event occured, and a change when it went to the end.

# %%
# further, as the words for the whole period is quite rare, I will divide the whole period into three sub-period to see the linguisic shifts in different periods.

# first is post 2000 to 2016

rawEmbeddings_2000, comparedEmbeddings_2000 = compareModels(speech_df[speech_df['year']>2000], 'year')
# Out:
# Embedding 2016

# %%
rawEmbeddings_2000.keys()
# Out:
# dict_keys([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016])

# %%
wordDivergences_2000 = findMostDivergent(comparedEmbeddings_2000)
# Out:
# Found 29 words to compare

# %%
wordDivergences_2000
# Out:
# [('day', 15.002363324165344),
#  ('way', 14.552630294114351),
#  ('years', 14.232958052307367),
#  ('need', 13.956219824030995),
#  ('tonight', 13.729039387777448),
#  ('american', 13.692850448191166),
#  ('health', 13.553037993609905),
#  ('congress', 13.393598156049848),
#  ('ve', 13.1991036105901),
#  ('people', 13.146390303969383),
#  ('united', 13.017685040831566),
#  ('work', 12.920671839267015),
#  ('security', 12.91249456256628),
#  ('states', 12.756411712616682),
#  ('world', 12.717936258763075),
#  ('americans', 12.60301127936691),
#  ('future', 12.36785813421011),
#  ('like', 12.358530167490244),
#  ('good', 12.27420787513256),
#  ('time', 12.26478385925293),
#  ('nation', 12.240214373916388),
#  ('know', 12.220409583300352),
#  ('children', 12.012571472674608),
#  ('military', 11.237187817692757),
#  ('government', 11.218350272625685),
#  ('help', 10.247313365340233),
#  ('country', 9.607767455279827),
#  ('new', 9.079490777105093),
#  ('america', 8.782753732055426)]

# %%
# we focus on the word "military"

targetWord = 'military'

pltDF = getDivergenceDF(targetWord, comparedEmbeddings_2000)
fig, ax = plt.subplots(figsize = (10, 7))
seaborn.heatmap(pltDF, ax = ax, annot = False) #set annot True for a lot more information
ax.set_xlabel("Starting year")
ax.set_ylabel("Final year")
ax.set_title("Yearly linguistic change for: '{}'".format(targetWord))
plt.show()
# Out:
# military

# %% [markdown]
# ### Inference/Comment
#
# We see a clear black block around 2009 to 2015. The point at 2009 is due to the end the Iraq war, so there is a linguistic shift. It may also due to that  We can also see that the year 2013 is the time when Obama announced the "Back to Asia" strategy and it may raise the military budget. Also, the time after 2014 is when the conflicts in South China Sea became intense.

# %%
# now check 1980-2000

rawEmbeddings_1980, comparedEmbeddings_1980 = compareModels(speech_df[(speech_df['year']>=1980) & (speech_df['year']<2000)], 'year')
# Out:
# Embedding 1999

# %%
wordDivergences_1980 = findMostDivergent(comparedEmbeddings_1980)
# Out:
# Found 38 words to compare

# %%
wordDivergences_1980[:]
# Out:
# [('national', 17.425518333911896),
#  ('day', 16.520739558152854),
#  ('tonight', 16.18819030188024),
#  ('long', 16.182557325810194),
#  ('free', 16.02113401889801),
#  ('americans', 15.989940509200096),
#  ('children', 15.898254781961441),
#  ('thank', 15.89763949625194),
#  ('support', 15.686382848769426),
#  ('congress', 15.58941349759698),
#  ('hope', 15.387074768543243),
#  ('today', 15.190469827502966),
#  ('war', 15.175476290285587),
#  ('way', 15.015772197395563),
#  ('peace', 15.010078802704811),
#  ('country', 14.520631227642298),
#  ('know', 14.486847281455994),
#  ('strong', 14.4063674621284),
#  ('year', 14.396049104630947),
#  ('let', 13.801244921982288),
#  ('ve', 13.529179751873016),
#  ('freedom', 13.268891263753176),
#  ('budget', 12.925906255841255),
#  ('president', 12.723832618445158),
#  ('states', 12.468296393752098),
#  ('years', 12.454113557934761),
#  ('future', 12.404991276562214),
#  ('nation', 12.077567681670189),
#  ('security', 12.056188888847828),
# ...

# %%
targetWord = 'strong'

pltDF = getDivergenceDF(targetWord, comparedEmbeddings_1980)
fig, ax = plt.subplots(figsize = (10, 7))
seaborn.heatmap(pltDF, ax = ax, annot = False) #set annot True for a lot more information
ax.set_xlabel("Starting year")
ax.set_ylabel("Final year")
ax.set_title("Yearly linguistic change for: '{}'".format(targetWord))
plt.show()
# Out:
# strong

# %% [markdown]
# ### Inference/Comment
#
# It should be noticed for the word "strong" during 1980-2000. The period of 1983-1986 is due to the strong policy made by Reagan from the oil crisis. The period of 1987-1990 is hard to explain, but it may due to the new president Bush, though the time does not quite match. The period of 1991-1996 mainly comes from the inauguration of Clinton, who had strong defense policy, called "Clintonism".

# %%
# then check 1960-1980

rawEmbeddings_1960, comparedEmbeddings_1960 = compareModels(speech_df[(speech_df['year']>1960) & (speech_df['year']<1980)], 'year')
# Out:
# Embedding 1979

# %%
wordDivergences_1960 = findMostDivergent(comparedEmbeddings_1960)
# Out:
# Found 25 words to compare

# %%
wordDivergences_1960
# Out:
# [('come', 9.621352851390839),
#  ('progress', 9.4605513215065),
#  ('today', 9.404075246304274),
#  ('past', 9.274087235331535),
#  ('home', 9.183400958776474),
#  ('future', 8.425245463848114),
#  ('people', 8.21377556398511),
#  ('nations', 8.190739177167416),
#  ('president', 7.974806688725948),
#  ('americans', 7.812324300408363),
#  ('country', 7.51842126250267),
#  ('years', 7.516969189047813),
#  ('year', 7.375251725316048),
#  ('great', 7.339936703443527),
#  ('time', 7.2891067415475845),
#  ('war', 7.229579195380211),
#  ('america', 6.9248024225234985),
#  ('states', 6.763554513454437),
#  ('government', 6.582531854510307),
#  ('american', 6.542309105396271),
#  ('new', 6.482072174549103),
#  ('peace', 6.364611208438873),
#  ('united', 6.11614453792572),
#  ('nation', 6.064025044441223),
#  ('world', 5.702144205570221)]

# %%
targetWord = 'war'

pltDF = getDivergenceDF(targetWord, comparedEmbeddings_1960)
fig, ax = plt.subplots(figsize = (10, 7))
seaborn.heatmap(pltDF, ax = ax, annot = False) #set annot True for a lot more information
ax.set_xlabel("Starting year")
ax.set_ylabel("Final year")
ax.set_title("Yearly linguistic change for: '{}'".format(targetWord))
plt.show()
# Out:
# war

# %%
targetWord = 'peace'

pltDF = getDivergenceDF(targetWord, comparedEmbeddings_1960)
fig, ax = plt.subplots(figsize = (10, 7))
seaborn.heatmap(pltDF, ax = ax, annot = False) #set annot True for a lot more information
ax.set_xlabel("Starting year")
ax.set_ylabel("Final year")
ax.set_title("Yearly linguistic change for: '{}'".format(targetWord))
plt.show()
# Out:
# peace

# %% [markdown]
# ### Inference/Comment
#
# This period is always around the Vietnam war from 1961-1973. So for both "war" and "peace", there is a linguistic shift at about 1970. Also, for "peace" in 1972-1974, it is the time for the negotiation, and the peaceful agreement was made at around 1973, which explains the block here.
